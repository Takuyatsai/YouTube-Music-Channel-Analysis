# %% [markdown]
# # 本篇為二次優化查看頻道的各個影片資訊

# %% [markdown]
# ## 同樣需要先導入package及設定需要的變數

# %%
from googleapiclient.discovery import build
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
api_service_name = "youtube"
api_version = "v3"
api_key = 'AIzaSyDuv01cLfrdAOaNT7ek2tGi9MfTURafy7Q'
youtube = build('youtube', 'v3', developerKey = api_key)

# %% [markdown]
# ## 匯入上一支程式所匯出的excel

# %%
channel_data = pd.read_excel('music_channel.xlsx', index_col=0)
channel_data
# Out:
#        Channel_name                                        Description  \
# 0    THE FIRST TAKE  A microphone and a white studio.\n\nAnd 1 rule...
# 1   Ayase / YOASOBI  ボカロP・Ayase、そしてAyaseがコンポーザーを務めるユニット・YOASOBIのYou...
# 2          kobasolo  毎週金曜19時更新!!音楽プロデューサー、ミュージシャンとして活動するコバソロが贈るエンター...
# 3                美波                      【美波 Official Youtube Channel】
# 4               星野源  音楽家・俳優・文筆家。\n2010年に1stアルバム『ばかのうた』にてソロデビュー。2016...
# 5           2CELLOS  The official home of 2CELLOS - we post our new...
# 6  Ru's Piano Ru味春捲  I’m RuRu, a piano youtuber from Taiwan.\nMakin...
# 7               Ado                                              元気です。
# 8         Pan Piano  台湾のピアニストです！ \nアニソンを弾いてます～ \n良かったら、チャンネル登録お願いしま...
#
#    Published Country  Subscribers       Views                  Playlist  \
# 0 2019-11-05      JP      6740000  2372659817  UU9zY_E8mcAo_Oq772LEZq8Q
# 1 2018-11-16      JP      3980000  2024089302  UUvpredjG93ifbCP1Y77JyFA
# 2 2008-06-30      JP      3000000  1418993882  UUDbQblY1XASbgqOXmy6FOFQ
# 3 2016-01-03      JP      1300000   410741180  UU2JzylaIF8qeowc7-5VwwmA
# 4 2015-05-08      JP      1460000   921206581  UUPKlrgZXnnb89nSeITvTdGA
# 5 2011-10-17      HR      6280000  1611623530  UUyjuFsbclXyntSRMBAILzbw
# 6 2018-03-14      TW      2260000   292118685  UUAYrMNl92jw6cpjdpBP8JyA
# 7 2018-08-18      JP      4000000  1392065788  UUln9P4Qm3-EAY4aiEPmRwEA
# 8 2016-07-27      TW      3350000   522089417  UUI7ktPB6toqucpkkCiolwLg
#
#    VideoCount                                      Channel_topic  \
# 0         422            ['Pop_music', 'Music_of_Asia', 'Music']
# 1         111            ['Pop_music', 'Music_of_Asia', 'Music']
# 2         499            ['Pop_music', 'Music_of_Asia', 'Music']
# 3           7  ['Pop_music', 'Music', 'Independent_music', 'R...
# 4          96            ['Pop_music', 'Music_of_Asia', 'Music']
# 5         213  ['Classical_music', 'Rock_music', 'Pop_music',...
# 6         396      ['Classical_music', 'Music_of_Asia', 'Music']
# 7          80  ['Pop_music', 'Electronic_music', 'Music', 'Mu...
# 8         545      ['Classical_music', 'Music_of_Asia', 'Music']
#
#                                                Image  \
# 0  https://yt3.ggpht.com/ytc/AMLnZu9H0hC1Gt8ZLT4V...
# 1  https://yt3.ggpht.com/ytc/AMLnZu_8o8D8yLIaOLRZ...
# 2  https://yt3.ggpht.com/ytc/AMLnZu-9S3og5Ip2zFAS...
# 3  https://yt3.ggpht.com/ytc/AMLnZu-a_zfDCmdvUihG...
# 4  https://yt3.ggpht.com/DLCVX6ArRGaHMe4k4N7Q_QtY...
# 5  https://yt3.ggpht.com/ytc/AMLnZu9V7gXnpIUCJYKK...
# 6  https://yt3.ggpht.com/ytc/AMLnZu_-ZUJbCF-LRu25...
# 7  https://yt3.ggpht.com/I3ckNVLPQq04aQklOnRctTEn...
# 8  https://yt3.ggpht.com/ytc/AMLnZu-uZODxdm-BCEo0...
#
#                                             Keywords
# 0                                                NaN
# 1                                                NaN
# 2  KOBASOLO コバソロ リトルタートルズ 音楽 music インディーズ little ...
# 3                                        シンガーソングライター
# 4  星野源 ほしのげん ホシノゲン "Gen Hoshino" "Hoshino Gen" "星...
# 5       2CELLOS Luka Sulic Stjepan Hauser Two Cellos
# 6  鋼琴 Ru味春捲 "Ru's Piano" "Ru Piano" Piano ピアノ "An...
# 7  アド あぼ ado "アド 歌い手" ADO Ado "Ado TikTok" "アド ティ...
# 8  鋼琴 演奏 ACG 動畫 漫畫 piano ピアノ アニメ 弾いてみた コスプレ パンピアノ...

# %% [markdown]
# ## 需要使用頻道的id才可取得頻道裡面，各個影片的 id
# 取得影片資訊：https://developers.google.com/youtube/v3/docs/playlistItems/list

# %%
df_ids = channel_data[['Channel_name', 'Playlist', 'VideoCount']]
df_ids
# Out:
#        Channel_name                  Playlist  VideoCount
# 0    THE FIRST TAKE  UU9zY_E8mcAo_Oq772LEZq8Q         422
# 1   Ayase / YOASOBI  UUvpredjG93ifbCP1Y77JyFA         111
# 2          kobasolo  UUDbQblY1XASbgqOXmy6FOFQ         499
# 3                美波  UU2JzylaIF8qeowc7-5VwwmA           7
# 4               星野源  UUPKlrgZXnnb89nSeITvTdGA          96
# 5           2CELLOS  UUyjuFsbclXyntSRMBAILzbw         213
# 6  Ru's Piano Ru味春捲  UUAYrMNl92jw6cpjdpBP8JyA         396
# 7               Ado  UUln9P4Qm3-EAY4aiEPmRwEA          80
# 8         Pan Piano  UUI7ktPB6toqucpkkCiolwLg         545

# %% [markdown]
# ## 需要先透過"頻道"的id，取得各個"影片"的id
# 影片一次最多只能取得50筆(一頁50部影片)，故api有提供nextPagetoken這個變數，若此變數為True，我們就能取得其他頁數的影片id

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
              part = 'contentDetails',
              playlistId = playlist_id,
              maxResults = 50) # 50 is max
    response = request.execute()
    
    video_ids = []
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages: 
        if next_page_token is None:
            more_pages = False
        else: # json存在nextPageToken，透過以下取得50以上的videos
            request = youtube.playlistItems().list(
                    part = 'contentDetails',
                    playlistId = playlist_id,
                    pageToken = next_page_token)
            response = request.execute()
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            next_page_token = response.get('nextPageToken')
    print('影片數量:', len(video_ids))
    return video_ids

# %%
playlist_id01 = channel_data.loc[channel_data['Channel_name'] == '2CELLOS', 'Playlist'].iloc[0]
playlist_id02 = channel_data.loc[channel_data['Channel_name'] == '美波', 'Playlist'].iloc[0]
playlist_id03 = channel_data.loc[channel_data['Channel_name'] == 'Ado', 'Playlist'].iloc[0]
playlist_id04 = channel_data.loc[channel_data['Channel_name'] == 'Ayase / YOASOBI', 'Playlist'].iloc[0]
playlist_id05 = channel_data.loc[channel_data['Channel_name'] == '星野源', 'Playlist'].iloc[0]
playlist_id06 = channel_data.loc[channel_data['Channel_name'] == 'kobasolo', 'Playlist'].iloc[0]
playlist_id07 = channel_data.loc[channel_data['Channel_name'] == "Ru's Piano Ru味春捲", 'Playlist'].iloc[0]
playlist_id08 = channel_data.loc[channel_data['Channel_name'] == 'Pan Piano', 'Playlist'].iloc[0]
playlist_id09 = channel_data.loc[channel_data['Channel_name'] == 'THE FIRST TAKE', 'Playlist'].iloc[0]

# %%
video_ids01 = get_video_ids(youtube, playlist_id01)
video_ids02 = get_video_ids(youtube, playlist_id02)
video_ids03 = get_video_ids(youtube, playlist_id03)
video_ids04 = get_video_ids(youtube, playlist_id04)
video_ids05 = get_video_ids(youtube, playlist_id05)
video_ids06 = get_video_ids(youtube, playlist_id06)
video_ids07 = get_video_ids(youtube, playlist_id07)
video_ids08 = get_video_ids(youtube, playlist_id08)
video_ids09 = get_video_ids(youtube, playlist_id09)
# Out:
# 影片數量: 214
# 影片數量: 7
# 影片數量: 80
# 影片數量: 112
# 影片數量: 96
# 影片數量: 500
# 影片數量: 396
# 影片數量: 546
# 影片數量: 422

# %% [markdown]
# ## 可透過以下測試查看"影片"的欄位資料

# %%
# def test_channel_video_detail(youtube, video_ids):
#     for i in range(0, len(video_ids), 50):
#         request = youtube.videos().list(
#         part = 'snippet, statistics,topicDetails, status, player, liveStreamingDetails',
#         id=','.join(video_ids[i:i+50]))
#     response = request.execute()
    
#     return response

# %%
# test_channel_video_detail(youtube, video_ids)

# %% [markdown]
# ## 查看過後抓取特定欄位並轉成將其轉為dictionary

# %%
def get_channel_video_detail(youtube, video_ids):
    
    all_video_stats = []
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
        part = 'snippet, statistics, topicDetails',
        id=','.join(video_ids[i:i+50]))
        response = request.execute()
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Description = video['snippet']['description'],
                               PublishedAt = video['snippet']['publishedAt'],
                               Language = '',
                               Views = video['statistics']['viewCount'],
                               Likes = video['statistics']['likeCount'],
                               CommentCount = '',
                               Image = video['snippet']['thumbnails']['high']['url'],
                               Tags = '',
                               Topic = '')
            if 'tags' in video['snippet']:video_stats['Tags'] = video['snippet']['tags']
            if 'topicDetails' in video:video_stats['Topic'] = video['topicDetails']['topicCategories']
            if 'defaultAudioLanguage' in video['snippet']:video_stats['Language'] = video['snippet']['defaultAudioLanguage']
            if 'commentCount' in video['statistics']:video_stats['CommentCount'] = video['statistics']['commentCount']
            all_video_stats.append(video_stats)
    return all_video_stats

# %%
video_details01 = get_channel_video_detail(youtube, video_ids01)
video_details02 = get_channel_video_detail(youtube, video_ids02)
video_details03 = get_channel_video_detail(youtube, video_ids03)
video_details04 = get_channel_video_detail(youtube, video_ids04)
video_details05 = get_channel_video_detail(youtube, video_ids05)
video_details06 = get_channel_video_detail(youtube, video_ids06)
video_details07 = get_channel_video_detail(youtube, video_ids07)
video_details08 = get_channel_video_detail(youtube, video_ids08)
video_details09 = get_channel_video_detail(youtube, video_ids09)

# %% [markdown]
# ## 取得過後同樣將其轉為DataFrame以方便查看

# %%
data_2CELLOS = pd.DataFrame(video_details01)
data_minami = pd.DataFrame(video_details02)
data_ado = pd.DataFrame(video_details03)
data_YOASOBI = pd.DataFrame(video_details04)
data_hoshinogen = pd.DataFrame(video_details05)
data_kobasolo = pd.DataFrame(video_details06)
data_rurupaino = pd.DataFrame(video_details07)
data_panpaino = pd.DataFrame(video_details08)
data_thefirsttake = pd.DataFrame(video_details09)

# %% [markdown]
# ## 同樣針對部分資料做整理，包含主題、資料型態等

# %%
def get_topic(df):
    col = []
    topic = []
    for i in df['Topic']:
        if i == '':
            col.append('')
        else:
            for j in range(len(i)):
                topic.append(i[j].split('/')[4])
            col.append(topic)
            topic = []
    df['Topic'] = col
    return df.head()

# %%
get_topic(data_2CELLOS) # 6
get_topic(data_minami)# 5
get_topic(data_ado) # 6
get_topic(data_YOASOBI) # 5
get_topic(data_hoshinogen)
get_topic(data_kobasolo) # 5
get_topic(data_rurupaino) # 4
get_topic(data_panpaino)# 5
get_topic(data_thefirsttake)# 6
# Out:
#                                                Title  \
# 0       Avril Lavigne - Complicated / THE FIRST TAKE
# 1           Avril Lavigne - Bite Me / THE FIRST TAKE
# 2                       森七菜 - スマイル  / THE FIRST TAKE
# 3               Kep1er - Wing Wing  / THE FIRST TAKE
# 4  Kep1er - WA DA DA (Japanese ver.) / THE FIRST ...
#
#                                          Description           PublishedAt  \
# 0                                                     2022-09-15T11:00:59Z
# 1  THE FIRST TAKE is a YouTube Channel dedicated ...  2022-09-14T13:00:13Z
# 2  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-09-09T13:00:13Z
# 3  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-09-07T13:00:14Z
# 4  第239回は、9人組グローバルガールズグループ・Kep1erが初登場。\n披露するのは全世界...  2022-09-06T06:36:42Z
#
#   Language    Views  Likes CommentCount  \
# 0       ja    24125   1921           20
# 1       en   789658  43130         1218
# 2       ja  1862719  57807         2021
# 3       ja  1993663  86778         2919
# 4       ja   954655  27327          193
#
#                                               Image  \
# 0  https://i.ytimg.com/vi/iqrT-mWBFPo/hqdefault.jpg
# 1  https://i.ytimg.com/vi/5MkLmapifks/hqdefault.jpg
# 2  https://i.ytimg.com/vi/lNDkODRoLvI/hqdefault.jpg
# 3  https://i.ytimg.com/vi/NJd0-O-IkPY/hqdefault.jpg
# 4  https://i.ytimg.com/vi/ZeMsSO6hpms/hqdefault.jpg
#
#                                                 Tags  \
# 0
# 1
# 2  [the first take, first take, ファーストテイク, ファステク, ...
# 3  [the first take, first take, ファーストテイク, Tokyo s...
# 4
#
#                                Topic
# 0                 [Music, Pop_music]
# 1                 [Music, Pop_music]
# 2  [Music, Music_of_Asia, Pop_music]
# 3  [Music, Music_of_Asia, Pop_music]
# 4  [Music, Music_of_Asia, Pop_music]

# %%
# data_2CELLOS[['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5', 'Topic6']] = pd.DataFrame(data_2CELLOS['Topic'].tolist())
# data_minami[['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5']] = pd.DataFrame(data_minami['Topic'].tolist())
# data_ado[['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5']] = pd.DataFrame(data_ado['Topic'].tolist())
# data_YOASOBI[['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5']] = pd.DataFrame(data_YOASOBI['Topic'].tolist())
# data_kobasolo[['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5']] = pd.DataFrame(data_kobasolo['Topic'].tolist())
# data_rurupaino[['Topic1', 'Topic2', 'Topic3', 'Topic4']] = pd.DataFrame(data_rurupaino['Topic'].tolist())
# data_panpaino[['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5']] = pd.DataFrame(data_panpaino['Topic'].tolist())
# data_thefirsttake[['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5', 'Topic6']] = pd.DataFrame(data_thefirsttake['Topic'].tolist())

# %%
test_df = data_2CELLOS.copy()
test_df.head()
# Out:
#                                                Title  \
# 0  2CELLOS - LIVE at Sydney Opera House [FULL CON...
# 1           2CELLOS - Wherever I Go [OFFICIAL VIDEO]
# 2       2CELLOS - Live in Zagreb 2016 [FULL CONCERT]
# 3        2CELLOS - World Tour 2022 - The Final Tour!
# 4      2CELLOS - Castle On The Hill [OFFICIAL VIDEO]
#
#                                          Description           PublishedAt  \
# 0  Get your tickets for the Final 2CELLOS World T...  2022-03-18T19:00:14Z
# 1  From the DEDICATED Extended Edition album, out...  2022-03-08T09:01:40Z
# 2  Get your tickets for the Final 2CELLOS World T...  2022-03-04T19:00:13Z
# 3  Come celebrate with us on our FINAL live tour!...  2022-03-03T12:51:13Z
# 4  From the DEDICATED Extended Edition album, out...  2022-02-18T11:49:53Z
#
#   Language    Views  Likes CommentCount  \
# 0           3506227  67020         3905
# 1            692457  21611          930
# 2            518129  13929         1412
# 3      zxx    84200   3141          241
# 4           1431157  45738         1968
#
#                                               Image  \
# 0  https://i.ytimg.com/vi/KbYgRXJmi6k/hqdefault.jpg
# 1  https://i.ytimg.com/vi/TcW1SsTBXyQ/hqdefault.jpg
# 2  https://i.ytimg.com/vi/MnQBqCX5alU/hqdefault.jpg
# 3  https://i.ytimg.com/vi/pCj48Bh5lWI/hqdefault.jpg
# 4  https://i.ytimg.com/vi/DemA2Q6V5oI/hqdefault.jpg
#
#                                                 Tags  \
# 0  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
# 1  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
# 2  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
# 3  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
# 4  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
#
#                                          Topic
# 0                     [Classical_music, Music]
# 1  [Classical_music, Independent_music, Music]
# 2         [Classical_music, Music, Rock_music]
# 3       [Independent_music, Music, Rock_music]
# 4                     [Classical_music, Music]

# %%
def topic_to_col(df):
    max_topic_num = max(df['Topic'].str.len())
    topic_col = []
    for i in range(max_topic_num):
        topic_col.append(f'Topic{i+1}')
    df1 = pd.DataFrame(df['Topic'].tolist(), columns = topic_col)
    df2 = pd.concat([df, df1], axis=1)
    return df2.head()

# %%
topic_to_col(data_2CELLOS)
topic_to_col(data_minami)
topic_to_col(data_ado)
topic_to_col(data_YOASOBI)
topic_to_col(data_hoshinogen)
topic_to_col(data_kobasolo)
topic_to_col(data_rurupaino)
topic_to_col(data_panpaino)
topic_to_col(data_thefirsttake)
# Out:
#                                                Title  \
# 0  2CELLOS - LIVE at Sydney Opera House [FULL CON...
# 1           2CELLOS - Wherever I Go [OFFICIAL VIDEO]
# 2       2CELLOS - Live in Zagreb 2016 [FULL CONCERT]
# 3        2CELLOS - World Tour 2022 - The Final Tour!
# 4      2CELLOS - Castle On The Hill [OFFICIAL VIDEO]
#
#                                          Description           PublishedAt  \
# 0  Get your tickets for the Final 2CELLOS World T...  2022-03-18T19:00:14Z
# 1  From the DEDICATED Extended Edition album, out...  2022-03-08T09:01:40Z
# 2  Get your tickets for the Final 2CELLOS World T...  2022-03-04T19:00:13Z
# 3  Come celebrate with us on our FINAL live tour!...  2022-03-03T12:51:13Z
# 4  From the DEDICATED Extended Edition album, out...  2022-02-18T11:49:53Z
#
#   Language    Views  Likes CommentCount  \
# 0           3506227  67020         3905
# 1            692457  21611          930
# 2            518129  13929         1412
# 3      zxx    84200   3141          241
# 4           1431157  45738         1968
#
#                                               Image  \
# 0  https://i.ytimg.com/vi/KbYgRXJmi6k/hqdefault.jpg
# 1  https://i.ytimg.com/vi/TcW1SsTBXyQ/hqdefault.jpg
# 2  https://i.ytimg.com/vi/MnQBqCX5alU/hqdefault.jpg
# 3  https://i.ytimg.com/vi/pCj48Bh5lWI/hqdefault.jpg
# 4  https://i.ytimg.com/vi/DemA2Q6V5oI/hqdefault.jpg
#
#                                                 Tags  \
# 0  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
# 1  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
# 2  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
# 3  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
# 4  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
#
#                                          Topic             Topic1  \
# 0                     [Classical_music, Music]    Classical_music
# 1  [Classical_music, Independent_music, Music]    Classical_music
# 2         [Classical_music, Music, Rock_music]    Classical_music
# 3       [Independent_music, Music, Rock_music]  Independent_music
# 4                     [Classical_music, Music]    Classical_music
#
#               Topic2      Topic3 Topic4 Topic5 Topic6
# 0              Music        None   None   None   None
# 1  Independent_music       Music   None   None   None
# 2              Music  Rock_music   None   None   None
# 3              Music  Rock_music   None   None   None
# 4              Music        None   None   None   None

# %%
def tag_to_col(df):
    max_topic_num = max(df['Tags'].str.len())
    topic_col = []
    for i in range(max_topic_num):
        topic_col.append(f'Tag{i+1}')
    df1 = pd.DataFrame(df['Tags'].tolist(), columns = topic_col)
    df2 = pd.concat([df, df1], axis=1)
    return df2.head()

# %%
tag_to_col(test_df)
# Out:
#                                                Title  \
# 0  2CELLOS - LIVE at Sydney Opera House [FULL CON...
# 1           2CELLOS - Wherever I Go [OFFICIAL VIDEO]
# 2       2CELLOS - Live in Zagreb 2016 [FULL CONCERT]
# 3        2CELLOS - World Tour 2022 - The Final Tour!
# 4      2CELLOS - Castle On The Hill [OFFICIAL VIDEO]
#
#                                          Description           PublishedAt  \
# 0  Get your tickets for the Final 2CELLOS World T...  2022-03-18T19:00:14Z
# 1  From the DEDICATED Extended Edition album, out...  2022-03-08T09:01:40Z
# 2  Get your tickets for the Final 2CELLOS World T...  2022-03-04T19:00:13Z
# 3  Come celebrate with us on our FINAL live tour!...  2022-03-03T12:51:13Z
# 4  From the DEDICATED Extended Edition album, out...  2022-02-18T11:49:53Z
#
#   Language    Views  Likes CommentCount  \
# 0           3506227  67020         3905
# 1            692457  21611          930
# 2            518129  13929         1412
# 3      zxx    84200   3141          241
# 4           1431157  45738         1968
#
#                                               Image  \
# 0  https://i.ytimg.com/vi/KbYgRXJmi6k/hqdefault.jpg
# 1  https://i.ytimg.com/vi/TcW1SsTBXyQ/hqdefault.jpg
# 2  https://i.ytimg.com/vi/MnQBqCX5alU/hqdefault.jpg
# 3  https://i.ytimg.com/vi/pCj48Bh5lWI/hqdefault.jpg
# 4  https://i.ytimg.com/vi/DemA2Q6V5oI/hqdefault.jpg
#
#                                                 Tags  \
# 0  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
# 1  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
# 2  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
# 3  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
# 4  [2CELLOS, Luka Sulic, Stjepan Hauser, cello, c...
#
#                                          Topic  ...     Tag42    Tag43  \
# 0                     [Classical_music, Music]  ...      Love  Romance
# 1  [Classical_music, Independent_music, Music]  ...      None     None
# 2         [Classical_music, Music, Rock_music]  ...  virtuoso     None
# 3       [Independent_music, Music, Rock_music]  ...      None     None
# 4                     [Classical_music, Music]  ...      None     None
#
#       Tag44            Tag45             Tag46        Tag47          Tag48  \
# 0  Romantic  Cinema Paradiso  Schindler's List  Hans Zimmer  John Williams
# 1      None             None              None         None           None
# 2      None             None              None         None           None
# 3      None             None              None         None           None
# 4      None             None              None         None           None
#
#           Tag49 Tag50 Tag51
# 0  James Horner  None  None
# 1          None  None  None
# 2          None  None  None
# 3          None  None  None
# 4          None  None  None
#
# [5 rows x 61 columns]

# %%
# max_topic_num = max(test_df['Topic'].str.len())
# topic_col = []
# for i in range(max_topic_num):
#     topic_col.append(f'Topic{i+1}')
# df1 = pd.DataFrame(test_df['Topic'].tolist(), columns = [topic_col])
# df2 = pd.concat([test_df, df1], axis=1)
# df2

# %%
from collections import Counter
all_terms = []
for terms in test_df['Tags']:
    all_terms.extend(terms)
sorted(dict(Counter(all_terms)).items(), key=lambda x:x[1], reverse=True)
# Out:
# [('2CELLOS', 212),
#  ('Luka Sulic', 198),
#  ('Stjepan Hauser', 197),
#  ('cello', 197),
#  ('cellist', 191),
#  ('two cellos', 179),
#  ('The Piano Guys', 168),
#  ('cover', 160),
#  ('cellists', 159),
#  ('crossover', 155),
#  ('2 Cellos', 149),
#  ('Glee', 148),
#  ('live', 108),
#  ('Lindsey Stirling', 89),
#  ('Croatia', 65),
#  ('Hauser', 57),
#  ('rock', 54),
#  ('Dusan Kranjc', 50),
#  ('music', 48),
#  ('drums', 48),
#  ('pop', 46),
#  ('classical music', 40),
#  ('Zagreb', 39),
#  ('drummer', 39),
#  ('classical', 35),
#  ('violin', 31),
#  ('concert', 31),
#  ('AC/DC', 29),
#  ('2 cellos', 29),
#  ('movie', 27),
#  ('great cellists', 26),
#  ('Italy', 24),
#  ('Arena di Verona', 22),
#  ('soundtrack', 21),
#  ('show', 21),
#  ('Angus Young', 20),
#  ('Roman', 20),
#  ('film', 19),
#  ('open air', 19),
#  ('summer', 19),
#  ('Michael Jackson', 18),
#  ('2015', 17),
#  ('2014', 17),
#  ('Arena Pula', 17),
#  ('Bob Ezrin', 17),
#  ('2016', 16),
#  ('2013', 16),
#  ('Colosseum', 15),
#  ('Australia', 14),
#  ('Sydney Opera House', 14),
#  ('Summer', 14),
#  ('Brian Johnson', 14),
#  ('Score', 14),
#  ('amphitheatre', 14),
#  ('Nirvana', 13),
#  ('orchestra', 13),
#  ('Bon Scott', 13),
#  ('Sydney', 12),
#  ('U2', 12),
#  ('hard rock', 12),
#  ('guitar', 12),
#  ('Sting', 12),
#  ('Zagreb Soloists', 12),
#  ('IN2ITION', 12),
#  ('Luka', 12),
#  ('Sulic', 12),
#  ('Stjepan', 12),
#  ('Hans Zimmer', 11),
#  ('piano', 11),
#  ('romantic', 11),
#  ("Rock N' Roll", 11),
#  ('Sydney Symphony Orchestra', 11),
#  ('Verona', 11),
#  ('Exit Festival', 11),
#  ('Novi Sad', 11),
#  ('strings', 10),
#  ('electric', 10),
#  ('Malcolm Young', 10),
#  ('colosseum', 10),
#  ('Coldplay', 10),
#  ('Smooth Criminal', 10),
#  ('Lisinski Concert Hall', 10),
#  ('Lisinski', 10),
#  ('2012', 10),
#  ('two', 10),
#  ('cellos', 10),
#  ('great', 10),
#  ('Zucchero', 9),
#  ('London Symphony Orchestra', 9),
#  ("Guns N' Roses", 9),
#  ('Zagrebacki Solisti', 9),
#  ('Arena Zagreb', 9),
#  ('Smooth', 9),
#  ('Criminal', 9),
#  ('Elton John', 8),
#  ('The Rolling Stones', 8),
#  ('Rihanna', 8),
#  ('Bach', 8),
#  ('Live', 8),
#  ('2011', 8),
#  ('Yamaha', 8),
#  ('silent', 8),
#  ('song', 7),
#  ('The Prodigy', 7),
#  ('Smells Like Teen Spirit', 7),
#  ('ac dc', 7),
#  ('You Shook Me All Night Long', 7),
#  ('Antonio Vivaldi', 7),
#  ('Muse', 7),
#  ('concerto', 7),
#  ('two violins', 7),
#  ('rock n roll', 6),
#  ('Iron Maiden', 6),
#  ('Oliver Dragojevic', 6),
#  ('Dave Grohl', 6),
#  ('Highway to Hell', 6),
#  ('Axl Rose', 6),
#  ('Dubrovnik', 6),
#  ('baroque', 6),
#  ('Johann Sebastian Bach', 6),
#  ('Amphitheatre', 6),
#  ('interview', 6),
#  ('Amphitheater', 6),
#  ('John Williams', 5),
#  ('Led Zeppelin', 5),
#  ('Avicii', 5),
#  ('anniversary', 5),
#  ('heavy metal', 5),
#  ('Calvin Harris', 5),
#  ('drum solo', 5),
#  ('Mick Jagger', 5),
#  ('Keith Richards', 5),
#  ('Kurt Cobain', 5),
#  ('Back in Black', 5),
#  ('Slash', 5),
#  ('score', 5),
#  ('LSO', 5),
#  ('King of Pop', 5),
#  ('suntory hall', 5),
#  ('tokyo', 5),
#  ('japan', 5),
#  ('2 violins', 5),
#  ('Lang Lang', 5),
#  ('Chris Martin', 5),
#  ('DVD', 5),
#  ('LIVE', 5),
#  ('in2ition', 5),
#  ('love', 4),
#  ('party', 4),
#  ('hauser', 4),
#  ('We Found Love', 4),
#  ('Mombasa', 4),
#  ('Inception', 4),
#  ('electric guitar', 4),
#  ('Charlie Watts', 4),
#  ('The Trooper', 4),
#  ('grunge', 4),
#  ('keyboard', 4),
#  ('passion', 4),
#  ('Thunderstruck', 4),
#  ('Welcome To The Jungle', 4),
#  ('The Police', 4),
#  ('tv', 4),
#  ('Bono', 4),
#  ('With Or Without You', 4),
#  ('J S Bach', 4),
#  ('Celloverse', 4),
#  ('Japan', 4),
#  ('intervju', 4),
#  ('funny', 4),
#  ('funniest moments', 4),
#  ('interviews', 4),
#  ('Serbia', 4),
#  ('Edge', 4),
#  ('The Book of Love', 4),
#  ('Peter Gabriel', 4),
#  ('Naya Rivera', 4),
#  ('Stradun', 4),
#  ('I Solisti di Zagreb', 4),
#  ('Festival', 4),
#  ('HAUSER', 3),
#  ('Opera', 3),
#  ('Titanic', 3),
#  ('The Godfather', 3),
#  ('Cinema Paradiso', 3),
#  ('James Horner', 3),
#  ('fun', 3),
#  ('dj', 3),
#  ('Leonardo Dicaprio', 3),
#  ('instrumental', 3),
#  ('Voodoo People', 3),
#  ('Ac Dc', 3),
#  ('Rock N Roll', 3),
#  ('Back In Black', 3),
#  ('Wake Me Up', 3),
#  ('Whole Lotta Love', 3),
#  ('AC DC', 3),
#  ('Vivaldi', 3),
#  ('Satisfaction', 3),
#  ('Highway To Hell', 3),
#  ('Ennio Morricone', 3),
#  ('Human Nature', 3),
#  ('film music', 3),
#  ('king of pop', 3),
#  ("rock n' roll", 3),
#  ('2017', 3),
#  ('Shape Of My Heart', 3),
#  ('Bad', 3),
#  ('Bono Vox', 3),
#  ('RV 522', 3),
#  ('Pula', 3),
#  ('promo', 3),
#  ('talk', 3),
#  ('Matthew Bellamy', 3),
#  ('pizzicato', 3),
#  ('Hard Rock', 3),
#  ('Green Day', 3),
#  ('Jimi Hendrix', 3),
#  ('Paul Gilbert', 3),
#  ('Racer X', 3),
#  ('Ellen DeGeneres', 3),
#  ('Clocks', 3),
#  ('Steve Vai', 3),
#  ('Red', 3),
#  ('Hot', 3),
#  ('Chili', 3),
#  ('Peppers', 3),
#  ('Flea', 3),
#  ('Cellos', 3),
#  ('Angus', 3),
#  ('Young', 3),
#  ('Dusan', 3),
#  ('Kranjc', 3),
#  ('Sveti', 3),
#  ('Vlaho', 3),
#  ('Gladiator', 2),
#  ('Braveheart', 2),
#  ("Breakfast at Tiffany's", 2),
#  ("Schindler's List", 2),
#  ('tour', 2),
#  ('ed sheeran', 2),
#  ('sulic', 2),
#  ('disco', 2),
#  ('Gibonni', 2),
#  ('Galeb i Ja', 2),
#  ('Zdenko Runjic', 2),
#  ('band', 2),
#  ("They Don't Care About Us", 2),
#  ('Sugar', 2),
#  ('Rock', 2),
#  ('Let There Be Cello', 2),
#  ('sea', 2),
#  ('Beethoven', 2),
#  ('Champions League', 2),
#  ('final', 2),
#  ("I Can't Get No", 2),
#  ('Stanley Myers', 2),
#  ('My Heart Will Go On', 2),
#  ('Celine Dion', 2),
#  ('James Cameron', 2),
#  ('Kate Winslet', 2),
#  ('Love Story', 2),
#  ('full concert', 2),
#  ('Morricone', 2),
#  ('Piazzolla', 2),
#  ('roman', 2),
#  ('Nino Rota', 2),
#  ('Marlon Brando', 2),
#  ('Al Pacino', 2),
#  ('Il Padrino', 2),
#  ('nature', 2),
#  ('Rock am Ring', 2),
#  ('RaR', 2),
#  ('Germany', 2),
#  ('opera', 2),
#  ('Rossini', 2),
#  ('overture', 2),
#  ('Resistance', 2),
#  ('Music', 2),
#  ('GOT', 2),
#  ('Roman colosseum', 2),
#  ('Viva La Vida', 2),
#  ('amphitheater', 2),
#  ('video', 2),
#  ('Air', 2),
#  ('Air on the G string', 2),
#  ('cajon', 2),
#  ('Tokyo', 2),
#  ('Leonardo DiCaprio', 2),
#  ('D minor', 2),
#  ('violins', 2),
#  ('A minor', 2),
#  ('Arena', 2),
#  ('Red Bull', 2),
#  ('radio', 2),
#  ('making of', 2),
#  ('humor', 2),
#  ('hilarious', 2),
#  ('hysterical', 2),
#  ('Prokurative', 2),
#  ('Split', 2),
#  ('Hrvatska', 2),
#  ('romantika', 2),
#  ('klavir', 2),
#  ('Karl Jenkins', 2),
#  ('Quincy Jones', 2),
#  ("Ten Summoner's Tales", 2),
#  ('tv show', 2),
#  ('tv shows', 2),
#  ('Purple Haze', 2),
#  ('Every Teardrop Is a Waterfall', 2),
#  ('kick', 2),
#  ('Technical Difficulties', 2),
#  ('Hurt', 2),
#  ('Nine Inch Nails', 2),
#  ('Johnny Cash', 2),
#  ('Trent Reznor', 2),
#  ('June', 2),
#  ('Supermassive Black Hole', 2),
#  ("Il Libro Dell' Amore", 2),
#  ('epk', 2),
#  ('Las Vegas', 2),
#  ('Welcome to the Jungle', 2),
#  ('Oh Well', 2),
#  ('Sky Ferreira', 2),
#  ('Every Breath You Take', 2),
#  ('Police', 2),
#  ('drummers', 2),
#  ('g minor', 2),
#  ('Californication', 2),
#  ('Anthony', 2),
#  ('Kiedis', 2),
#  ('Chad', 2),
#  ('Smith', 2),
#  ('in', 2),
#  ('AC', 2),
#  ('DC', 2),
#  ('Brian', 2),
#  ('Johnson', 2),
#  ('Bon', 2),
#  ('Scott', 2),
#  ('Silent', 2),
#  ('ac', 2),
#  ('dc', 2),
#  ('Concert', 2),
#  ('Hall', 2),
#  ('yamaha', 2),
#  ('hall', 2),
#  ('Michael', 2),
#  ('Jackson', 2),
#  ('You', 2),
#  ('Smells', 2),
#  ('Like', 2),
#  ('Teen', 2),
#  ('Spirit', 2),
#  ('Kurt', 2),
#  ('Cobain', 2),
#  ('Sv', 2),
#  ('Cover', 2),
#  ('iTunes', 2),
#  ('Roundhouse', 2),
#  ('London', 2),
#  ('Symphony', 1),
#  ('Orchestra', 1),
#  ('classic', 1),
#  ('Game of Thrones', 1),
#  ('Love', 1),
#  ('Romance', 1),
#  ('Romantic', 1),
#  ('onerepublic', 1),
#  ('one republic', 1),
#  ('ryan tedder', 1),
#  ('Brent Kutzle', 1),
#  ('Oh My My', 1),
#  ('wherever i go', 1),
#  ('joy', 1),
#  ('Prodigy', 1),
#  ('virtuoso', 1),
#  ('world tour 2022', 1),
#  ('castle on the hill', 1),
#  ('divide', 1),
#  ('axel rose', 1),
#  ('guns n roses', 1),
#  ('sweet child of mine', 1),
#  ('sweet child o mine', 1),
#  ('slash', 1),
#  ('aerosmith', 1),
#  ('cryin', 1),
#  ('get a grip', 1),
#  ('Alicia Silverstone', 1),
#  ("i don't care", 1),
#  ('green screen', 1),
#  ('justin bieber', 1),
#  ('imagine dragons', 1),
#  ('demons', 1),
#  ('night visions', 1),
#  ('best of', 1),
#  ('greatest hits', 1),
#  ('music playlist', 1),
#  ('playlist', 1),
#  ('bon jovi', 1),
#  ("livin' on a prayer", 1),
#  ('slippery when wet', 1),
#  ('beat', 1),
#  ('Oliver', 1),
#  ('RIP', 1),
#  ('live Zagreb', 1),
#  ('Sto To Bjese Ljubav', 1),
#  ('holywood', 1),
#  ('techno', 1),
#  ('electronic', 1),
#  ('electric cello', 1),
#  ('metal', 1),
#  ('Metallica', 1),
#  ('Cosi Celeste', 1),
#  ('Cheb Mami', 1),
#  ('Baila Morena', 1),
#  ('Partigiano Reggiano', 1),
#  ('Italian', 1),
#  ('Croatian', 1),
#  ('Medley', 1),
#  ('Vilo Moja', 1),
#  ('Dalmatia', 1),
#  ('Ne Dirajte Mi Ravnicu', 1),
#  ('Slavonia', 1),
#  ('Dalmacija', 1),
#  ('Slavonija', 1),
#  ('Miroslav Skoro', 1),
#  ('Vinko Coce', 1),
#  ('klapa', 1),
#  ('DJ', 1),
#  ('Ultra', 1),
#  ('Fireworks', 1),
#  ('Kashmir', 1),
#  ('Hallelujah', 1),
#  ('Leonard Cohen', 1),
#  ('Pirates of the Caribbean', 1),
#  ('Johnny Depp', 1),
#  ('pirate', 1),
#  ('ship', 1),
#  ('Karaka', 1),
#  ('ocean', 1),
#  ('Venezia', 1),
#  ('Four Seasons', 1),
#  ('Autumn', 1),
#  ('Winter', 1),
#  ('Spring', 1),
#  ('Mozart', 1),
#  ('Ronaldo', 1),
#  ('Cristiano Ronaldo', 1),
#  ('CR7', 1),
#  ('Real Madrid', 1),
#  ('Liverpool', 1),
#  ('FC Liverpool', 1),
#  ('Kiev', 1),
#  ('Ukraine', 1),
#  ('Soccer', 1),
#  ('Footbal', 1),
#  ('stadium', 1),
#  ('anthem', 1),
#  ('theme song', 1),
#  ('UEFA', 1),
#  ('UCL', 1),
#  ('2018', 1),
#  ('Seven Nation Army', 1),
#  ('The White Stripes', 1),
#  ('football', 1),
#  ('soccer', 1),
#  ('sport', 1),
#  ('Survivor', 1),
#  ('Eye Of The Tiger', 1),
#  ('Rocky', 1),
#  ('Sylvester Stallone', 1),
#  ('Rocky Balboa', 1),
#  ('box', 1),
#  ('boxing', 1),
#  ('fight', 1),
#  ('fighting', 1),
#  ('ring', 1),
#  ('UFC', 1),
#  ('MMA', 1),
#  ('octagon', 1),
#  ('Ronnie Wood', 1),
#  ('Luka SUlic', 1),
#  ('Ed Sheeran', 1),
#  ('Perfect', 1),
#  ('Piano Guys', 1),
#  ('For The Love Of A Princess', 1),
#  ('Mel Gibson', 1),
#  ('instruments', 1),
#  ('cinema', 1),
#  ('The Deer Hunter', 1),
#  ('Cavatina', 1),
#  ('actor', 1),
#  ('actress', 1),
#  ('SYdney Opera House', 1),
#  ('new album', 1),
#  ('Phil Rudd', 1),
#  ('main theme', 1),
#  ('love theme', 1),
#  ('corssover', 1),
#  ('Despacito', 1),
#  ('Latino', 1),
#  ('Spanish', 1),
#  ('Luis Fonsi', 1),
#  ('Daddy Yankee', 1),
#  ('reggaeton', 1),
#  ('Latin', 1),
#  ('Justin Bieber', 1),
#  ('Chariots of Fire', 1),
#  ('Titles', 1),
#  ('Vangelis', 1),
#  ('Bol', 1),
#  ('Brac', 1),
#  ('Zlatni Rat', 1),
#  ('beach', 1),
#  ('virtuosity', 1),
#  ('May It Be', 1),
#  ('The Lord of the Rings', 1),
#  ('Enya', 1),
#  ('theme', 1),
#  ('jewish', 1),
#  ('holocaust', 1),
#  ('Steven Spielger', 1),
#  ('2cellos', 1),
#  ('stjepan hauser', 1),
#  ('luka sulic', 1),
#  ('gladiator', 1),
#  ('now we are free', 1),
#  ('Crossover', 1),
#  ('Cello', 1),
#  ('Cellist', 1),
#  ('Classical', 1),
#  ('Soundtrack', 1),
#  ('Now We Are Free', 1),
#  ('Russell Crowe', 1),
#  ('Moon River', 1),
#  ('Game Of Thrones', 1),
#  ('medley', 1),
#  ('Fields Of Gold', 1),
#  ('Dominic Miller', 1),
#  ('moon river', 1),
#  ("breakfast at tiffany's", 1),
#  ('audrey hepburn', 1),
#  ('game of thrones', 1),
#  ('Ramin djawadi', 1),
#  ("They Don't Really Care About Us", 1),
#  ('The Show Must Go On', 1),
#  ('Freddie Mercury', 1),
#  ('Queen', 1),
#  ('Brian May', 1),
#  ('intimate', 1),
#  ('J. S. Bach', 1),
#  ('I can Get No Satisfaction', 1),
#  ('ennio morricone', 1),
#  ('the mission', 1),
#  ('gabriels oboe', 1),
#  ('hans zimmer', 1),
#  ('mombasa', 1),
#  ('inception', 1),
#  ('michael jackson', 1),
#  ('smooth criminal', 1),
#  ('Ludwig van Beethoven', 1),
#  ('5th Symphony', 1),
#  ('Donald Trump', 1),
#  ('bach', 1),
#  ('air on a g string', 1),
#  ('air in g', 1),
#  ('lindsey stirling', 1),
#  ('app', 1),
#  ('u2', 1),
#  ('with or without you', 1),
#  ('Handel', 1),
#  ('Massenet', 1),
#  ('Monti', 1),
#  ('Full concert', 1),
#  ('Rachmaninov', 1),
#  ('Kreisler', 1),
#  ('Bruch', 1),
#  ('solo', 1),
#  ('Suntory Hall', 1),
#  ('birthday', 1),
#  ('5th', 1),
#  ('vision', 1),
#  ('Vatroslav Lisisnki Concert Hall', 1),
#  ('Vivace', 1),
#  ('Vatroslav Lisinski Concert Hall', 1),
#  ('allegro', 1),
#  ('Concerto', 1),
#  ('Documentary', 1),
#  ('From Pula 2 Pula', 1),
#  ('Suite No 3', 1),
#  ('Astor Piazzolla', 1),
#  ('Oblivion', 1),
#  ('tango', 1),
#  ('dance', 1),
#  ('Argentina', 1),
#  ("Gabriel's Oboe", 1),
#  ('The Mission', 1),
#  ('concert hall', 1),
#  ('part 4', 1),
#  ('Ivan Ivanovic', 1),
#  ('original', 1),
#  ('arrangement', 1),
#  ('Hysteria', 1),
#  ('seagull', 1),
#  ('Lipa Moja', 1),
#  ('Splitski festival', 1),
#  ('Live And Let Die', 1),
#  ('Paul McCartney', 1),
#  ('The Beatles', 1),
#  ('pianist', 1),
#  ('superstar', 1),
#  ('James Bond', 1),
#  ('part 3', 1),
#  ('Full Concert', 1),
#  ('July', 1),
#  ('new', 1),
#  ('single', 1),
#  ('announcement', 1),
#  ('Exit festival', 1),
#  ('Thriller', 1),
#  ('Darko Drinovac', 1),
#  ('Willem Tell Overture', 1),
#  ('Gioachino Rossini', 1),
#  ('Heavy Metal', 1),
#  ('nerds', 1),
#  ('rock star', 1),
#  ('Grunge', 1),
#  ('I Will Wait', 1),
#  ('Mumford & Sons', 1),
#  ('Plitvice Lakes', 1),
#  ('National Park', 1),
#  ('Plitvicka Jezera', 1),
#  ('beautiful', 1),
#  ('waterfalls', 1),
#  ('part 2', 1),
#  ('comedy', 1),
#  ('Red Hot Chilli Peppers', 1),
#  ('The Bachelor', 1),
#  ('ABC', 1),
#  ('Baroque', 1),
#  ('Back To The Future', 1),
#  ('Chuck Berry', 1),
#  ('Johnny Be Good', 1),
#  ('Michael J. Fox', 1),
#  ('sonata', 1),
#  ('Summer 2013', 1),
#  ('The Magnetic Fields', 1),
#  ("Il Libro Dell'Amore", 1),
#  ('Good Riddance', 1),
#  ('Time of Your Life', 1),
#  ('Billie Joe Armstrong', 1),
#  ('Fields of Gold', 1),
#  ('balad', 1),
#  ('Fragile', 1),
#  ('ballad', 1),
#  ('Roman Colosseum', 1),
#  ('June 2012', 1),
#  ('Appetite for Disctruction', 1),
#  ('Drum and Bass', 1),
#  ('Ellen', 1),
#  ('Where The Streets Have No Name', 1),
#  ('Rome', 1),
#  ('iTunes Festival', 1),
#  ('talking about', 1),
#  ('about', 1),
#  ('Jay Leno', 1),
#  ('The Tonight Show', 1),
#  ('opening act', 1),
#  ('Million Dollar Piano', 1),
#  ('Caesars Palace', 1),
#  ('Kagemusha', 1),
#  ('Docomo', 1),
#  ('commercial', 1),
#  ('the piano guys', 1),
#  ('the making of in2ition', 1),
#  ('Il Libro Del Amore', 1),
#  ('studio 45', 1),
#  ('Ellen Show', 1),
#  ('Access Hollywood', 1),
#  ('sheep', 1),
#  ('Antena Zagreb', 1),
#  ('press conference', 1),
#  ('Conn TV', 1),
#  ('Deutsche Welle', 1),
#  ('Magnetic Fields', 1),
#  ('In2ition', 1),
#  ('Benedictus', 1),
#  ('Zagreb Philharmonic Orchestra', 1),
#  ('the great cellists', 1),
#  ('Armed Man', 1),
#  ('Ivo Lipanovic', 1),
#  ('conductor', 1),
#  ('Prelude', 1),
#  ('Dmitri Shostakovich', 1),
#  ('dueling cellists', 1),
#  ('dueling cellos', 1),
#  ('Steve Hunter', 1),
#  ('guitarist', 1),
#  ('Bang Bang', 1),
#  ('Cher', 1),
#  ('Sonny Bono', 1),
#  ('Kill Bill', 1),
#  ('Zodiac', 1),
#  ('Nancy Sinatra', 1),
#  ('Fleetwood Mac', 1),
#  ('crazy moments', 1),
#  ('passionate', 1),
#  ('intense', 1),
#  ('broken bow', 1),
#  ('breaks the bow', 1),
#  ('Curt Cobain', 1),
#  ('Violoncelles Vibrez!', 1),
#  ('Giovanni Sollima', 1),
#  ('Flying Bulls', 1),
#  ('Hangar 7', 1),
#  ('Salzburg', 1),
#  ('Rainer Wilke', 1),
#  ('Mirko Flaim', 1),
#  ('When I Come Around', 1),
#  ('Split Riva', 1),
#  ('two years around the world', 1),
#  ('2 years', 1),
#  ('Sky Ferrera', 1),
#  ('Art on Ice', 1),
#  ('1 cello', 1),
#  ('1cello', 1),
#  ('one cello', 1),
#  ('concerto for two violins', 1),
#  ('BWV 1043', 1),
#  ('2nd movement', 1),
#  ('Largo ma non tanto', 1),
#  ('Zagreb Soloist', 1),
#  ('Violoncelles', 1),
#  ('Vibrez', 1),
#  ('Giovanni', 1),
#  ('Sollima', 1),
#  ('rocking', 1),
#  ('audience', 1),
#  ('belt', 1),
#  ('Belgrade', 1),
#  ('Beograd', 1),
#  ('Srbija', 1),
#  ('Sava Centar', 1),
#  ('LUKA SULIC', 1),
#  ('With or Without You', 1),
#  ('8 kat', 1),
#  ('hrt', 1),
#  ('Danijela Trbovic', 1),
#  ('osmi kat', 1),
#  ('Allegro', 1),
#  ('Largo', 1),
#  ('il Libro del Amore', 1),
#  ('Magnetic Field', 1),
#  ('concerto for two cellos', 1),
#  ('largo', 1),
#  ('charity', 1),
#  ('Back', 1),
#  ('Black', 1),
#  ('ACDC', 1),
#  ('Holidays', 1),
#  ('adriatic coast', 1),
#  ('Highway', 1),
#  ('to', 1),
#  ('Hell', 1),
#  ('Viva', 1),
#  ('La', 1),
#  ('Vida', 1),
#  ('Chris', 1),
#  ('Martin', 1),
#  ('Boss', 1),
#  ('Loop', 1),
#  ('Pedal', 1),
#  ('RC-2', 1),
#  ('Human', 1),
#  ('Nature', 1),
#  ('Shook', 1),
#  ('Me', 1),
#  ('All', 1),
#  ('Night', 1),
#  ('Long', 1),
#  ('Dubrovacke', 1),
#  ('Ljetne', 1),
#  ('Igre', 1),
#  ('drum', 1),
#  ('Nirvana (band)', 1),
#  ('Dave', 1),
#  ('Grohl', 1),
#  ('Kirst', 1),
#  ('Novoselic', 1),
#  ('Fields', 1),
#  ('of', 1),
#  ('Gold', 1),
#  ('The', 1),
#  ('festival', 1),
#  ('With', 1),
#  ('or', 1),
#  ('Without', 1),
#  ('Sony', 1)]

# %%
from wordcloud import WordCloud

wordcloud = WordCloud()
wordcloud.generate_from_frequencies(frequencies=dict(Counter(all_terms)))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
data_2CELLOS[['Tags1', 'Tags2', 'Tags3', 'Tags4', 'Tags5']] = pd.DataFrame(data_2CELLOS['Tags'].tolist())
data_YOASOBI[['Tags1', 'Tags2', 'Tags3', 'Tags4', 'Tags5']] = pd.DataFrame(data_YOASOBI['Tags'].tolist())
data_ado[['Tags1', 'Tags2', 'Tags3', 'Tags4', 'Tags5']] = pd.DataFrame(data_ado['Tags'].tolist())
data_hoshinogen[['Tags1', 'Tags2', 'Tags3', 'Tags4', 'Tags5']] = pd.DataFrame(data_hoshinogen['Tags'].tolist())
data_kobasolo[['Tags1', 'Tags2', 'Tags3', 'Tags4', 'Tags5']] = pd.DataFrame(data_kobasolo['Tags'].tolist())
data_rurupaino[['Tags1', 'Tags2', 'Tags3', 'Tags4', 'Tags5']] = pd.DataFrame(data_rurupaino['Tags'].tolist())
data_panpaino[['Tags1', 'Tags2', 'Tags3', 'Tags4', 'Tags5']] = pd.DataFrame(data_panpaino['Tags'].tolist())
data_thefirsttake[['Tags1', 'Tags2', 'Tags3', 'Tags4', 'Tags5']] = pd.DataFrame(data_thefirsttake['Tags'].tolist())

# %% [markdown]
# ## 資料型態轉換

# %%
def columns_type_format(df):
    df['PublishedAt'] = pd.to_datetime(df['PublishedAt']).dt.date
    df['Views'] = pd.to_numeric(df['Views'])
    df['Likes'] = pd.to_numeric(df['Likes'])
    df['CommentCount'] = pd.to_numeric(df['CommentCount'])
    return df.head()

# %%
columns_type_format(data_2CELLOS)
columns_type_format(data_minami)
columns_type_format(data_ado)
columns_type_format(data_YOASOBI)
columns_type_format(data_hoshinogen)
columns_type_format(data_kobasolo)
columns_type_format(data_rurupaino)
columns_type_format(data_panpaino)
columns_type_format(data_thefirsttake)
# Out:
#                                                Title  \
# 0                       森七菜 - スマイル  / THE FIRST TAKE
# 1               Kep1er - Wing Wing  / THE FIRST TAKE
# 2  Kep1er - WA DA DA (Japanese ver.) / THE FIRST ...
# 3       Avril Lavigne - Complicated / THE FIRST TAKE
# 4                  Creepy Nuts - 堕天 / THE FIRST TAKE
#
#                                          Description PublishedAt Language  \
# 0  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-09-09       ja
# 1  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-09-07       ja
# 2  第239回は、9人組グローバルガールズグループ・Kep1erが初登場。\n披露するのは全世界...  2022-09-06       ja
# 3  THE FIRST TAKE is a YouTube Channel dedicated ...  2022-09-02       en
# 4  第238回は、”日本三連覇のラッパー”R-指定と、”世界一のDJ”DJ松永による1MC1DJ...  2022-08-31       ja
#
#      Views   Likes  CommentCount  \
# 0  1106317   46333          1669
# 1  1596473   80218          2700
# 2   563213   17247           124
# 3  5183532  229049          8438
# 4   354419   12138           110
#
#                                               Image  \
# 0  https://i.ytimg.com/vi/lNDkODRoLvI/hqdefault.jpg
# 1  https://i.ytimg.com/vi/NJd0-O-IkPY/hqdefault.jpg
# 2  https://i.ytimg.com/vi/ZeMsSO6hpms/hqdefault.jpg
# 3  https://i.ytimg.com/vi/_P9zR5KaPsc/hqdefault.jpg
# 4  https://i.ytimg.com/vi/q2jz1O4GLWQ/hqdefault.jpg
#
#                                                 Tags  \
# 0  [the first take, first take, ファーストテイク, ファステク, ...
# 1  [the first take, first take, ファーストテイク, Tokyo s...
# 2                                       [[, , , , ]]
# 3  [the first take, first take, ファーストテイク, ファステク, ...
# 4                                       [[, , , , ]]
#
#                                            Topic  ...         Topic2  \
# 0              [Music, Music_of_Asia, Pop_music]  ...  Music_of_Asia
# 1              [Music, Music_of_Asia, Pop_music]  ...  Music_of_Asia
# 2              [Music, Music_of_Asia, Pop_music]  ...  Music_of_Asia
# 3  [Country_music, Music, Pop_music, Rock_music]  ...          Music
# 4                         [Hip_hop_music, Music]  ...          Music
#
#       Topic3      Topic4 Topic5 Topic6           Tags1       Tags2     Tags3  \
# 0  Pop_music        None   None   None  the first take  first take  ファーストテイク
# 1  Pop_music        None   None   None  the first take  first take  ファーストテイク
# 2  Pop_music        None   None   None      [, , , , ]        None      None
# 3  Pop_music  Rock_music   None   None  the first take  first take  ファーストテイク
# 4       None        None   None   None      [, , , , ]        None      None
#
#           Tags4   Tags5
# 0         ファステク    一発撮り
# 1  Tokyo sounds  Kep1er
# 2          None    None
# 3         ファステク    一発撮り
# 4          None    None
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 將影片資訊寫入到一個excel中的不同個sheet

# %%
import os 
import numpy as np

# 開一個新的excel並把多個df寫到同excel不同sheet
path = os.path.join(os.getcwd(), 'channel_video_details.xlsx') # 設定路徑及檔名
writer = pd.ExcelWriter(path, engine='xlsxwriter') # 指定引擎openpyxl

data_ado.to_excel(writer, sheet_name='Ado', index=False)
data_thefirsttake.to_excel(writer, sheet_name='The First Take', index=False)
data_2CELLOS.to_excel(writer, sheet_name='2CELLOS', index=False)
data_minami.to_excel(writer, sheet_name='美波', index=False)
data_hoshinogen.to_excel(writer, sheet_name='星野源', index=False)
data_kobasolo.to_excel(writer, sheet_name='Kobasolo', index=False)
data_rurupaino.to_excel(writer, sheet_name='Ru味春捲 Paino', index=False)
data_panpaino.to_excel(writer, sheet_name='Pan Paino', index=False)
data_YOASOBI.to_excel(writer, sheet_name='Yoasobi', index=False)
writer.save()

# %% [markdown]
# ## 可簡易的查看頻道前10名的影片內容，以TheFirstTake為例

# %%
top10_videos = data_thefirsttake.sort_values(by='Views', ascending=False).head(10)
top10_videos
# Out:
#                                                  Title  \
# 388                 DISH// (北村匠海) - 猫 / THE FIRST TAKE
# 375                    YOASOBI - 夜に駆ける / THE HOME TAKE
# 415                        LiSA - 紅蓮華 / THE FIRST TAKE
# 328                      優里 - ドライフラワー / THE FIRST TAKE
# 274                     YOASOBI - 群青  / THE FIRST TAKE
# 334                          LiSA - 炎 / THE FIRST TAKE
# 325  LiSA×Uru - 再会 (produced by Ayase) / THE FIRST ...
# 157                       優里 - ベテルギウス / THE FIRST TAKE
# 315                Def Tech - My Way  / THE FIRST TAKE
# 125  milet×Aimer×幾田りら - おもかげ (produced by Vaundy) /...
#
#                                            Description PublishedAt Language  \
# 388  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2020-03-20       ja
# 375  「THE HOME TAKE」は、アーティストの自宅やプライベートスタジオから、一発撮りで届...  2020-05-15       ja
# 415  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-12-06       ja
# 328  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2020-10-30       ja
# 274  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2021-02-26       ja
# 334  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2020-10-16       ja
# 325  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2020-11-06       ja
# 157  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2021-10-13       ja
# 315  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2020-11-20       ja
# 125  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2021-12-17       ja
#
#          Views    Likes  CommentCount  \
# 388  187995169  1176258         47174
# 375  129802633  1673826         64622
# 415  125393123  1345499         45489
# 328  104590811   604214         19844
# 274   76427898  1046535         34785
# 334   58895051   797328         28276
# 325   58662951   538477         17078
# 157   44004924   341464          8606
# 315   37238670   494909         18088
# 125   34817657   487088         13994
#
#                                                 Image  \
# 388  https://i.ytimg.com/vi/gsT6eKsnT0M/hqdefault.jpg
# 375  https://i.ytimg.com/vi/j1hft9Wjq9U/hqdefault.jpg
# 415  https://i.ytimg.com/vi/MpYy6wwqxoo/hqdefault.jpg
# 328  https://i.ytimg.com/vi/yXZd7xVdpJ0/hqdefault.jpg
# 274  https://i.ytimg.com/vi/NyUTYwZe_l4/hqdefault.jpg
# 334  https://i.ytimg.com/vi/4Q9DWZLaY2U/hqdefault.jpg
# 325  https://i.ytimg.com/vi/impSuIygMiQ/hqdefault.jpg
# 157  https://i.ytimg.com/vi/-n790YakYKc/hqdefault.jpg
# 315  https://i.ytimg.com/vi/9ZG9G3v1RPk/hqdefault.jpg
# 125  https://i.ytimg.com/vi/Z2Z9V-4DMGw/hqdefault.jpg
#
#                                                   Tags  \
# 388  [the first take, first take, ファーストテイク, ファステク, ...
# 375  [the first take, first take, ファーストテイク, ファステク, ...
# 415  [the first take, first take, ファーストテイク, ファステク, ...
# 328  [the first take, first take, ファーストテイク, ファステク, ...
# 274  [the first take, first take, ファーストテイク, ファステク, ...
# 334  [the first take, first take, ファーストテイク, ファステク, ...
# 325  [the first take, first take, ファーストテイク, ファステク, ...
# 157  [the first take, first take, ファーストテイク, ファステク, ...
# 315  [the first take, first take, ファーストテイク, ファステク, ...
# 125  [the first take, first take, ファーストテイク, ファステク, ...
#
#                                              Topic  ...         Topic2  \
# 388              [Music, Music_of_Asia, Pop_music]  ...  Music_of_Asia
# 375              [Music, Music_of_Asia, Pop_music]  ...  Music_of_Asia
# 415             [Music, Music_of_Asia, Rock_music]  ...  Music_of_Asia
# 328              [Music, Music_of_Asia, Pop_music]  ...  Music_of_Asia
# 274  [Music, Music_of_Asia, Pop_music, Rock_music]  ...  Music_of_Asia
# 334              [Music, Music_of_Asia, Pop_music]  ...  Music_of_Asia
# 325              [Music, Music_of_Asia, Pop_music]  ...  Music_of_Asia
# 157              [Music, Music_of_Asia, Pop_music]  ...  Music_of_Asia
# 315          [Hip_hop_music, Music, Music_of_Asia]  ...          Music
# 125              [Music, Music_of_Asia, Pop_music]  ...  Music_of_Asia
#
#             Topic3      Topic4 Topic5 Topic6           Tags1       Tags2  \
# 388      Pop_music        None   None   None  the first take  first take
# 375      Pop_music        None   None   None  the first take  first take
# 415     Rock_music        None   None   None  the first take  first take
# 328      Pop_music        None   None   None  the first take  first take
# 274      Pop_music  Rock_music   None   None  the first take  first take
# 334      Pop_music        None   None   None  the first take  first take
# 325      Pop_music        None   None   None  the first take  first take
# 157      Pop_music        None   None   None  the first take  first take
# 315  Music_of_Asia        None   None   None  the first take  first take
# 125      Pop_music        None   None   None  the first take  first take
#
#         Tags3  Tags4 Tags5
# 388  ファーストテイク  ファステク  一発撮り
# 375  ファーストテイク  ファステク  一発撮り
# 415  ファーストテイク  ファステク  一発撮り
# 328  ファーストテイク  ファステク  一発撮り
# 274  ファーストテイク  ファステク  一発撮り
# 334  ファーストテイク  ファステク  一発撮り
# 325  ファーストテイク  ファステク  一発撮り
# 157  ファーストテイク  ファステク  一発撮り
# 315  ファーストテイク  ファステク  一発撮り
# 125  ファーストテイク  ファステク  一発撮り
#
# [10 rows x 21 columns]

# %%
fig = plt.figure(figsize=(10, 5)) 
color = ['#5975a4', '#cc8963', '#5f9e6e', '#b55e60', '#857aab', '#8d7866', '#d095bf', '#8c8c8c', '#c1b37f', '#00E3E3']
# creating the bar plot 
plt.barh(top10_videos['Title'], top10_videos['Views'], color=color)
plt.xlabel("Views(bn)",fontsize=20) 
plt.ylabel("Songs",fontsize=20) 
plt.title("Top 10 Ado Videos",fontsize=20)
plt.show()

# %% [markdown]
# ## 加入月份

# %%
data_thefirsttake['Month'] = pd.to_datetime(data_thefirsttake['PublishedAt']).dt.strftime('%b')
data_thefirsttake
# Out:
#                                                  Title  \
# 0                         森七菜 - スマイル  / THE FIRST TAKE
# 1                 Kep1er - Wing Wing  / THE FIRST TAKE
# 2    Kep1er - WA DA DA (Japanese ver.) / THE FIRST ...
# 3         Avril Lavigne - Complicated / THE FIRST TAKE
# 4                    Creepy Nuts - 堕天 / THE FIRST TAKE
# ..                                                 ...
# 415                        LiSA - 紅蓮華 / THE FIRST TAKE
# 416                        adieu - 天気 / THE FIRST TAKE
# 417  Cö shu Nie - asphyxia （piano ver.) / THE FIRST...
# 418          Rude-α  - It's only love / THE FIRST TAKE
# 419                   adieu  - ナラタージュ / THE FIRST TAKE
#
#                                            Description PublishedAt Language  \
# 0    「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-09-09       ja
# 1    「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-09-07       ja
# 2    第239回は、9人組グローバルガールズグループ・Kep1erが初登場。\n披露するのは全世界...  2022-09-06       ja
# 3    THE FIRST TAKE is a YouTube Channel dedicated ...  2022-09-02       en
# 4    第238回は、”日本三連覇のラッパー”R-指定と、”世界一のDJ”DJ松永による1MC1DJ...  2022-08-31       ja
# ..                                                 ...         ...      ...
# 415  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-12-06       ja
# 416  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-12-04       ja
# 417  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-11-29       ja
# 418  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-11-23       ja
# 419  「THE FIRST TAKE」アーティストの一発撮りのパフォーマンスをよりリアルに、\n鮮...  2019-11-15       ja
#
#          Views    Likes  CommentCount  \
# 0      1106317    46333          1669
# 1      1596473    80218          2700
# 2       563213    17247           124
# 3      5183532   229049          8438
# 4       354419    12138           110
# ..         ...      ...           ...
# 415  125393123  1345499         45489
# 416    1277183    13791           372
# 417    5936425   164170          3680
# 418    2498200    44038          1453
# 419    5590709    81624          1727
#
#                                                 Image  \
# 0    https://i.ytimg.com/vi/lNDkODRoLvI/hqdefault.jpg
# 1    https://i.ytimg.com/vi/NJd0-O-IkPY/hqdefault.jpg
# 2    https://i.ytimg.com/vi/ZeMsSO6hpms/hqdefault.jpg
# 3    https://i.ytimg.com/vi/_P9zR5KaPsc/hqdefault.jpg
# 4    https://i.ytimg.com/vi/q2jz1O4GLWQ/hqdefault.jpg
# ..                                                ...
# 415  https://i.ytimg.com/vi/MpYy6wwqxoo/hqdefault.jpg
# 416  https://i.ytimg.com/vi/FT6Wf8EWYwA/hqdefault.jpg
# 417  https://i.ytimg.com/vi/eWPYxw_yqW4/hqdefault.jpg
# 418  https://i.ytimg.com/vi/qdPbnrqs5UQ/hqdefault.jpg
# 419  https://i.ytimg.com/vi/YTKuKuD-gmE/hqdefault.jpg
#
#                                                   Tags  \
# 0    [the first take, first take, ファーストテイク, ファステク, ...
# 1    [the first take, first take, ファーストテイク, Tokyo s...
# 2                                         [[, , , , ]]
# 3    [the first take, first take, ファーストテイク, ファステク, ...
# 4                                         [[, , , , ]]
# ..                                                 ...
# 415  [the first take, first take, ファーストテイク, ファステク, ...
# 416  [the first take, first take, ファーストテイク, ファステク, ...
# 417  [the first take, first take, ファーストテイク, ファステク, ...
# 418  [the first take, first take, ファーストテイク, ファステク, ...
# 419  [the first take, first take, ファーストテイク, ファステク, ...
#
#                                              Topic  ...      Topic3  \
# 0                [Music, Music_of_Asia, Pop_music]  ...   Pop_music
# 1                [Music, Music_of_Asia, Pop_music]  ...   Pop_music
# 2                [Music, Music_of_Asia, Pop_music]  ...   Pop_music
# 3    [Country_music, Music, Pop_music, Rock_music]  ...   Pop_music
# 4                           [Hip_hop_music, Music]  ...        None
# ..                                             ...  ...         ...
# 415             [Music, Music_of_Asia, Rock_music]  ...  Rock_music
# 416              [Music, Music_of_Asia, Pop_music]  ...   Pop_music
# 417                         [Music, Music_of_Asia]  ...        None
# 418              [Music, Music_of_Asia, Pop_music]  ...   Pop_music
# 419                         [Music, Music_of_Asia]  ...        None
#
#          Topic4 Topic5 Topic6           Tags1       Tags2     Tags3  \
# 0          None   None   None  the first take  first take  ファーストテイク
# 1          None   None   None  the first take  first take  ファーストテイク
# 2          None   None   None      [, , , , ]        None      None
# 3    Rock_music   None   None  the first take  first take  ファーストテイク
# 4          None   None   None      [, , , , ]        None      None
# ..          ...    ...    ...             ...         ...       ...
# 415        None   None   None  the first take  first take  ファーストテイク
# 416        None   None   None  the first take  first take  ファーストテイク
# 417        None   None   None  the first take  first take  ファーストテイク
# 418        None   None   None  the first take  first take  ファーストテイク
# 419        None   None   None  the first take  first take  ファーストテイク
#
#             Tags4   Tags5 Month
# 0           ファステク    一発撮り   Sep
# 1    Tokyo sounds  Kep1er   Sep
# 2            None    None   Sep
# 3           ファステク    一発撮り   Sep
# 4            None    None   Aug
# ..            ...     ...   ...
# 415         ファステク    一発撮り   Dec
# 416         ファステク    一発撮り   Dec
# 417         ファステク    一発撮り   Nov
# 418         ファステク    一発撮り   Nov
# 419         ファステク    一発撮り   Nov
#
# [420 rows x 22 columns]

# %% [markdown]
# ## 顯示月份上傳影片數量及排序

# %%
videos_per_month = data_thefirsttake.groupby('Month', as_index=False).size()
videos_per_month
# Out:
#    Month  size
# 0    Apr    35
# 1    Aug    38
# 2    Dec    38
# 3    Feb    34
# 4    Jan    34
# 5    Jul    34
# 6    Jun    43
# 7    Mar    39
# 8    May    35
# 9    Nov    34
# 10   Oct    27
# 11   Sep    29

# %%
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
              'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories = sort_order, ordered=True)
videos_per_month = videos_per_month.sort_index()
videos_per_month
# Out:
#       Month  size
# Month
# Jan     Jan    34
# Feb     Feb    34
# Mar     Mar    39
# Apr     Apr    35
# May     May    35
# Jun     Jun    43
# Jul     Jul    34
# Aug     Aug    38
# Sep     Sep    29
# Oct     Oct    27
# Nov     Nov    34
# Dec     Dec    38

# %%
fig = plt.figure(figsize=(10, 5)) 
color = ['#5975a4', '#cc8963', '#5f9e6e', '#b55e60', '#857aab', '#8d7866', '#d095bf', '#8c8c8c', '#c1b37f', '#00E3E3', '#ff7801','#9edcea']
# creating the bar plot 
plt.bar(videos_per_month['Month'], videos_per_month['size'], color=color) 
  
plt.xlabel("Month",fontsize=20) 
plt.ylabel("Quantity",fontsize=20) 
plt.title("TheFirstTake Videos Uploaded History",fontsize=20)
plt.show()
