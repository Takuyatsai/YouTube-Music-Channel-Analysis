# %% [markdown]
# # 本篇為更深入查看頻道的各個影片資訊

# %% [markdown]
# ## 同樣需要先導入package及設定需要的變數

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
api_service_name = "youtube"
api_version = "v3"
api_key = 'AIzaSyDuv01cLfrdAOaNT7ek2tGi9MfTURafy7Q'
youtube = build('youtube', 'v3', developerKey = api_key)

# %% [markdown]
# ## 匯入上一支程式所匯出的excel

# %%
channel_data = pd.read_excel('music_channel.xlsx', index_col=0)
channel_data
# Out:
#        Channel_name                                        Description  \
# 0               Ado                                              元気です。
# 1                美波                      【美波 Official Youtube Channel】
# 2          kobasolo  毎週金曜19時更新!!音楽プロデューサー、ミュージシャンとして活動するコバソロが贈るエンター...
# 3   Ayase / YOASOBI  ボカロP・Ayase、そしてAyaseがコンポーザーを務めるユニット・YOASOBIのYou...
# 4  Ru's Piano Ru味春捲  I’m RuRu, a piano youtuber from Taiwan.\nMakin...
# 5         Pan Piano  台湾のピアニストです！ \nアニソンを弾いてます～ \n良かったら、チャンネル登録お願いしま...
# 6               星野源  音楽家・俳優・文筆家。\n2010年に1stアルバム『ばかのうた』にてソロデビュー。2016...
# 7    THE FIRST TAKE  A microphone and a white studio.\n\nAnd 1 rule...
# 8           2CELLOS  The official home of 2CELLOS - we post our new...
#
#    Published Country  Subscribers       Views                  Playlist  \
# 0 2018-08-18      JP      3900000  1339411388  UUln9P4Qm3-EAY4aiEPmRwEA
# 1 2016-01-03      JP      1300000   408773492  UU2JzylaIF8qeowc7-5VwwmA
# 2 2008-06-30      JP      3000000  1415750412  UUDbQblY1XASbgqOXmy6FOFQ
# 3 2018-11-16      JP      3970000  2007955926  UUvpredjG93ifbCP1Y77JyFA
# 4 2018-03-14      TW      2250000   290367664  UUAYrMNl92jw6cpjdpBP8JyA
# 5 2016-07-27      TW      3350000   520227536  UUI7ktPB6toqucpkkCiolwLg
# 6 2015-05-08      JP      1460000   917609111  UUPKlrgZXnnb89nSeITvTdGA
# 7 2019-11-05      JP      6690000  2343182969  UU9zY_E8mcAo_Oq772LEZq8Q
# 8 2011-10-17      HR      6270000  1607694129  UUyjuFsbclXyntSRMBAILzbw
#
#    VideoCount                                      Channel_topic  \
# 0          80  ['Electronic_music', 'Independent_music', 'Mus...
# 1           7  ['Independent_music', 'Pop_music', 'Music_of_A...
# 2         499            ['Music', 'Music_of_Asia', 'Pop_music']
# 3         109            ['Music', 'Music_of_Asia', 'Pop_music']
# 4         393      ['Music', 'Music_of_Asia', 'Classical_music']
# 5         541      ['Music', 'Music_of_Asia', 'Classical_music']
# 6          96            ['Music', 'Music_of_Asia', 'Pop_music']
# 7         417            ['Music', 'Music_of_Asia', 'Pop_music']
# 8         213  ['Music', 'Rock_music', 'Classical_music', 'Po...
#
#                                                Image  \
# 0  https://yt3.ggpht.com/I3ckNVLPQq04aQklOnRctTEn...
# 1  https://yt3.ggpht.com/ytc/AMLnZu-a_zfDCmdvUihG...
# 2  https://yt3.ggpht.com/ytc/AMLnZu-9S3og5Ip2zFAS...
# 3  https://yt3.ggpht.com/ytc/AMLnZu_8o8D8yLIaOLRZ...
# 4  https://yt3.ggpht.com/ytc/AMLnZu_-ZUJbCF-LRu25...
# 5  https://yt3.ggpht.com/ytc/AMLnZu-uZODxdm-BCEo0...
# 6  https://yt3.ggpht.com/DLCVX6ArRGaHMe4k4N7Q_QtY...
# 7  https://yt3.ggpht.com/ytc/AMLnZu9H0hC1Gt8ZLT4V...
# 8  https://yt3.ggpht.com/ytc/AMLnZu9V7gXnpIUCJYKK...
#
#                                             Keywords
# 0  アド あぼ ado "アド 歌い手" ADO Ado "Ado TikTok" "アド ティ...
# 1                                        シンガーソングライター
# 2  KOBASOLO コバソロ リトルタートルズ 音楽 music インディーズ little ...
# 3                                                NaN
# 4  鋼琴 Ru味春捲 "Ru's Piano" "Ru Piano" Piano ピアノ "An...
# 5  鋼琴 演奏 ACG 動畫 漫畫 piano ピアノ アニメ 弾いてみた コスプレ パンピアノ...
# 6  星野源 ほしのげん ホシノゲン "Gen Hoshino" "Hoshino Gen" "星...
# 7                                                NaN
# 8       2CELLOS Luka Sulic Stjepan Hauser Two Cellos

# %% [markdown]
# ## 需要使用頻道的id才可取得頻道裡面，各個影片的 id
# 取得影片資訊：https://developers.google.com/youtube/v3/docs/playlistItems/list

# %%
df_ids = channel_data[['Channel_name', 'Playlist', 'VideoCount']]
df_ids
# Out:
#        Channel_name                  Playlist  VideoCount
# 0               Ado  UUln9P4Qm3-EAY4aiEPmRwEA          80
# 1                美波  UU2JzylaIF8qeowc7-5VwwmA           7
# 2          kobasolo  UUDbQblY1XASbgqOXmy6FOFQ         499
# 3   Ayase / YOASOBI  UUvpredjG93ifbCP1Y77JyFA         109
# 4  Ru's Piano Ru味春捲  UUAYrMNl92jw6cpjdpBP8JyA         393
# 5         Pan Piano  UUI7ktPB6toqucpkkCiolwLg         541
# 6               星野源  UUPKlrgZXnnb89nSeITvTdGA          96
# 7    THE FIRST TAKE  UU9zY_E8mcAo_Oq772LEZq8Q         417
# 8           2CELLOS  UUyjuFsbclXyntSRMBAILzbw         213

# %% [markdown]
# ## 需要先透過"頻道"的id，取得各個"影片"的id
# 影片一次最多只能取得50筆(一頁50部影片)，故api有提供nextPagetoken這個變數，若此變數為True，我們就能取得其他頁數的影片id

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
              part = 'contentDetails',
              playlistId = playlist_id,
              maxResults = 50) # 50 is max
    response = request.execute()
    
    video_ids = []
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages: 
        if next_page_token is None:
            more_pages = False
        else: # json存在nextPageToken，透過以下取得50以上的videos
            request = youtube.playlistItems().list(
                    part = 'contentDetails',
                    playlistId = playlist_id,
                    pageToken = next_page_token)
            response = request.execute()
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            next_page_token = response.get('nextPageToken')
    print('影片數量:', len(video_ids))
    return video_ids

# %%
playlist_id01 = channel_data.loc[channel_data['Channel_name'] == '2CELLOS', 'Playlist'].iloc[0]
playlist_id02 = channel_data.loc[channel_data['Channel_name'] == '美波', 'Playlist'].iloc[0]
playlist_id03 = channel_data.loc[channel_data['Channel_name'] == 'Ado', 'Playlist'].iloc[0]
playlist_id04 = channel_data.loc[channel_data['Channel_name'] == 'Ayase / YOASOBI', 'Playlist'].iloc[0]
playlist_id05 = channel_data.loc[channel_data['Channel_name'] == '星野源', 'Playlist'].iloc[0]
playlist_id06 = channel_data.loc[channel_data['Channel_name'] == 'kobasolo', 'Playlist'].iloc[0]
playlist_id07 = channel_data.loc[channel_data['VideoCount'] == 393, 'Playlist'].iloc[0]
playlist_id08 = channel_data.loc[channel_data['Channel_name'] == 'Pan Piano', 'Playlist'].iloc[0]
playlist_id09 = channel_data.loc[channel_data['Channel_name'] == 'THE FIRST TAKE', 'Playlist'].iloc[0]

# %%
video_ids01 = get_video_ids(youtube, playlist_id01)
video_ids02 = get_video_ids(youtube, playlist_id02)
video_ids03 = get_video_ids(youtube, playlist_id03)
video_ids04 = get_video_ids(youtube, playlist_id04)
video_ids05 = get_video_ids(youtube, playlist_id05)
video_ids06 = get_video_ids(youtube, playlist_id06)
video_ids07 = get_video_ids(youtube, playlist_id07)
video_ids08 = get_video_ids(youtube, playlist_id08)
video_ids09 = get_video_ids(youtube, playlist_id09)
# Out:
# 影片數量: 214
# 影片數量: 7
# 影片數量: 80
# 影片數量: 111
# 影片數量: 96
# 影片數量: 500
# 影片數量: 395
# 影片數量: 543
# 影片數量: 420

# %% [markdown]
# ## 可透過以下測試查看"影片"的欄位資料

# %%
# def test_channel_video_detail(youtube, video_ids):
#     for i in range(0, len(video_ids), 50):
#         request = youtube.videos().list(
#         part = 'snippet, statistics,topicDetails, status, player, liveStreamingDetails',
#         id=','.join(video_ids[i:i+50]))
#     response = request.execute()
    
#     return response

# %%
# test_channel_video_detail(youtube, video_ids)

# %% [markdown]
# ## 查看過後抓取特定欄位並轉成將其轉為dictionary

# %%
def get_channel_video_detail(youtube, video_ids):
    
    all_video_stats = []
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
        part = 'snippet, statistics, topicDetails',
        id=','.join(video_ids[i:i+50]))
        response = request.execute()
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Description = video['snippet']['description'],
                               PublishedAt = video['snippet']['publishedAt'],
                               Language = '',
                               Views = video['statistics']['viewCount'],
                               Likes = video['statistics']['likeCount'],
                               CommentCount = '',
                               Image = video['snippet']['thumbnails']['high']['url'],
                               Tags = '',
                               Topic = '')
            if 'tags' in video['snippet']:video_stats['Tags'] = video['snippet']['tags']
            if 'topicDetails' in video:video_stats['Topic'] = video['topicDetails']['topicCategories']
            if 'defaultAudioLanguage' in video['snippet']:video_stats['Language'] = video['snippet']['defaultAudioLanguage']
            if 'commentCount' in video['statistics']:video_stats['CommentCount'] = video['statistics']['commentCount']
            all_video_stats.append(video_stats)
    return all_video_stats

# %%
video_details01 = get_channel_video_detail(youtube, video_ids01)
video_details02 = get_channel_video_detail(youtube, video_ids02)
video_details03 = get_channel_video_detail(youtube, video_ids03)
video_details04 = get_channel_video_detail(youtube, video_ids04)
video_details05 = get_channel_video_detail(youtube, video_ids05)
video_details06 = get_channel_video_detail(youtube, video_ids06)
video_details07 = get_channel_video_detail(youtube, video_ids07)
video_details08 = get_channel_video_detail(youtube, video_ids08)
video_details09 = get_channel_video_detail(youtube, video_ids09)

# %% [markdown]
# ## 取得過後同樣將其轉為DataFrame以方便查看

# %%
data_2CELLOS = pd.DataFrame(video_details01)
data_minami = pd.DataFrame(video_details02)
data_ado = pd.DataFrame(video_details03)
data_YOASOBI = pd.DataFrame(video_details04)
data_hoshinogen = pd.DataFrame(video_details05)
data_kobasolo = pd.DataFrame(video_details06)
data_rurupaino = pd.DataFrame(video_details07)
data_panpaino = pd.DataFrame(video_details08)
data_thefirsttake = pd.DataFrame(video_details09)

# %% [markdown]
# ## 同樣針對部分資料做整理，包含主題、資料型態等

# %%
def get_topic(df):
    col = []
    topic = []
    for i in df['Topic']:
        if i == '':
            col.append('')
        else:
            for j in range(len(i)):
                topic.append(i[j].split('/')[4])
            col.append(topic)
            topic = []
    df['Topic'] = col
    return df.head()

# %%
get_topic(data_2CELLOS)
get_topic(data_minami)
get_topic(data_ado)
get_topic(data_YOASOBI)
get_topic(data_hoshinogen)
get_topic(data_kobasolo)
get_topic(data_rurupaino)
get_topic(data_panpaino)
get_topic(data_thefirsttake)
# Out:
#                                                Title  \
# 0                       森七菜 - スマイル  / THE FIRST TAKE
# 1               Kep1er - Wing Wing  / THE FIRST TAKE
# 2  Kep1er - WA DA DA (Japanese ver.) / THE FIRST ...
# 3       Avril Lavigne - Complicated / THE FIRST TAKE
# 4                  Creepy Nuts - 堕天 / THE FIRST TAKE
#
#                                          Description           PublishedAt  \
# 0  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-09-09T13:00:13Z
# 1  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-09-07T13:00:14Z
# 2  第239回は、9人組グローバルガールズグループ・Kep1erが初登場。\n披露するのは全世界...  2022-09-06T06:36:42Z
# 3  THE FIRST TAKE is a YouTube Channel dedicated ...  2022-09-02T13:00:14Z
# 4  第238回は、”日本三連覇のラッパー”R-指定と、”世界一のDJ”DJ松永による1MC1DJ...  2022-08-31T15:00:38Z
#
#   Language    Views   Likes CommentCount  \
# 0       ja   508806   32008         1331
# 1       ja  1309287   73246         2551
# 2       ja   398552   12517          104
# 3       en  4957711  222417         8260
# 4       ja   319667   10962           99
#
#                                               Image  \
# 0  https://i.ytimg.com/vi/lNDkODRoLvI/hqdefault.jpg
# 1  https://i.ytimg.com/vi/NJd0-O-IkPY/hqdefault.jpg
# 2  https://i.ytimg.com/vi/ZeMsSO6hpms/hqdefault.jpg
# 3  https://i.ytimg.com/vi/_P9zR5KaPsc/hqdefault.jpg
# 4  https://i.ytimg.com/vi/q2jz1O4GLWQ/hqdefault.jpg
#
#                                                 Tags  \
# 0  [the first take, first take, ファーストテイク, ファステク, ...
# 1  [the first take, first take, ファーストテイク, Tokyo s...
# 2
# 3  [the first take, first take, ファーストテイク, ファステク, ...
# 4
#
#                                Topic
# 0  [Music, Music_of_Asia, Pop_music]
# 1  [Music, Music_of_Asia, Pop_music]
# 2  [Music, Music_of_Asia, Pop_music]
# 3  [Country_music, Music, Pop_music]
# 4             [Hip_hop_music, Music]

# %%
def get_top_ten_tags(df):
    top_ten = []
    for col in range(len(df['Tags'])):
        for tag in df['Tags'][col]:
            if tag == '':top_ten = None
            else:
                if len(top_ten) < 10:
                    top_ten.append(tag)
        df['Tags'][col] = top_ten
    return df

# %%
get_top_ten_tags(data_thefirsttake)
# Out:
#                                                  Title  \
# 0                         森七菜 - スマイル  / THE FIRST TAKE
# 1                 Kep1er - Wing Wing  / THE FIRST TAKE
# 2    Kep1er - WA DA DA (Japanese ver.) / THE FIRST ...
# 3         Avril Lavigne - Complicated / THE FIRST TAKE
# 4                    Creepy Nuts - 堕天 / THE FIRST TAKE
# ..                                                 ...
# 415                        LiSA - 紅蓮華 / THE FIRST TAKE
# 416                        adieu - 天気 / THE FIRST TAKE
# 417  Cö shu Nie - asphyxia （piano ver.) / THE FIRST...
# 418          Rude-α  - It's only love / THE FIRST TAKE
# 419                   adieu  - ナラタージュ / THE FIRST TAKE
#
#                                            Description           PublishedAt  \
# 0    「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-09-09T13:00:13Z
# 1    「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-09-07T13:00:14Z
# 2    第239回は、9人組グローバルガールズグループ・Kep1erが初登場。\n披露するのは全世界...  2022-09-06T06:36:42Z
# 3    THE FIRST TAKE is a YouTube Channel dedicated ...  2022-09-02T13:00:14Z
# 4    第238回は、”日本三連覇のラッパー”R-指定と、”世界一のDJ”DJ松永による1MC1DJ...  2022-08-31T15:00:38Z
# ..                                                 ...                   ...
# 415  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-12-06T13:00:10Z
# 416  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-12-04T13:00:13Z
# 417  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-11-29T13:00:12Z
# 418  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-11-23T12:00:11Z
# 419  「THE FIRST TAKE」アーティストの一発撮りのパフォーマンスをよりリアルに、\n鮮...  2019-11-15T13:00:11Z
#
#     Language      Views    Likes CommentCount  \
# 0         ja     508806    32008         1331
# 1         ja    1309287    73246         2551
# 2         ja     398552    12517          104
# 3         en    4957711   222417         8260
# 4         ja     319667    10962           99
# ..       ...        ...      ...          ...
# 415       ja  125350313  1345088        45485
# 416       ja    1276689    13786          372
# 417       ja    5933505   164114         3682
# 418       ja    2497248    44029         1453
# 419       ja    5587778    81579         1727
#
#                                                 Image  \
# 0    https://i.ytimg.com/vi/lNDkODRoLvI/hqdefault.jpg
# 1    https://i.ytimg.com/vi/NJd0-O-IkPY/hqdefault.jpg
# 2    https://i.ytimg.com/vi/ZeMsSO6hpms/hqdefault.jpg
# 3    https://i.ytimg.com/vi/_P9zR5KaPsc/hqdefault.jpg
# 4    https://i.ytimg.com/vi/q2jz1O4GLWQ/hqdefault.jpg
# ..                                                ...
# 415  https://i.ytimg.com/vi/MpYy6wwqxoo/hqdefault.jpg
# 416  https://i.ytimg.com/vi/FT6Wf8EWYwA/hqdefault.jpg
# 417  https://i.ytimg.com/vi/eWPYxw_yqW4/hqdefault.jpg
# 418  https://i.ytimg.com/vi/qdPbnrqs5UQ/hqdefault.jpg
# 419  https://i.ytimg.com/vi/YTKuKuD-gmE/hqdefault.jpg
#
#                                                   Tags  \
# 0    [the first take, first take, ファーストテイク, ファステク, ...
# 1    [the first take, first take, ファーストテイク, ファステク, ...
# 2    [the first take, first take, ファーストテイク, ファステク, ...
# 3    [the first take, first take, ファーストテイク, ファステク, ...
# 4    [the first take, first take, ファーストテイク, ファステク, ...
# ..                                                 ...
# 415  [the first take, first take, ファーストテイク, ファステク, ...
# 416  [the first take, first take, ファーストテイク, ファステク, ...
# 417  [the first take, first take, ファーストテイク, ファステク, ...
# 418  [the first take, first take, ファーストテイク, ファステク, ...
# 419  [the first take, first take, ファーストテイク, ファステク, ...
#
#                                   Topic
# 0     [Music, Music_of_Asia, Pop_music]
# 1     [Music, Music_of_Asia, Pop_music]
# 2     [Music, Music_of_Asia, Pop_music]
# 3     [Country_music, Music, Pop_music]
# 4                [Hip_hop_music, Music]
# ..                                  ...
# 415  [Music, Music_of_Asia, Rock_music]
# 416   [Music, Music_of_Asia, Pop_music]
# 417              [Music, Music_of_Asia]
# 418   [Music, Music_of_Asia, Pop_music]
# 419              [Music, Music_of_Asia]
#
# [420 rows x 10 columns]

# %%
data_thefirsttake['Tags'][20]
# Out:
# ['the first take',
#  'first take',
#  'ファーストテイク',
#  'ファステク',
#  '一発撮り',
#  '緊張感',
#  'COLORS',
#  'DSCVR',
#  'Tokyo sounds',
#  'lute']

# %%
top_ten = []
for tag in data_thefirsttake['Tags'][20]:
    if len(top_ten) < 10:
        top_ten.append(tag)
        continue
top_ten
# Out:
# ['the first take',
#  'first take',
#  'ファーストテイク',
#  'ファステク',
#  '一発撮り',
#  '緊張感',
#  'COLORS',
#  'DSCVR',
#  'Tokyo sounds',
#  'lute']

# %% [markdown]
# ## 資料型態轉換

# %%
def columns_type_format(df):
    df['PublishedAt'] = pd.to_datetime(df['PublishedAt']).dt.date
    df['Views'] = pd.to_numeric(df['Views'])
    df['Likes'] = pd.to_numeric(df['Likes'])
    df['CommentCount'] = pd.to_numeric(df['CommentCount'])
    return df.head()

# %%
columns_type_format(data_2CELLOS)
columns_type_format(data_minami)
columns_type_format(data_ado)
columns_type_format(data_YOASOBI)
columns_type_format(data_hoshinogen)
columns_type_format(data_kobasolo)
columns_type_format(data_rurupaino)
columns_type_format(data_panpaino)
columns_type_format(data_thefirsttake)
# Out:
#                                                Title  \
# 0                       森七菜 - スマイル  / THE FIRST TAKE
# 1               Kep1er - Wing Wing  / THE FIRST TAKE
# 2  Kep1er - WA DA DA (Japanese ver.) / THE FIRST ...
# 3       Avril Lavigne - Complicated / THE FIRST TAKE
# 4                  Creepy Nuts - 堕天 / THE FIRST TAKE
#
#                                          Description PublishedAt Language  \
# 0  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-09-09       ja
# 1  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-09-07       ja
# 2  第239回は、9人組グローバルガールズグループ・Kep1erが初登場。\n披露するのは全世界...  2022-09-06       ja
# 3  THE FIRST TAKE is a YouTube Channel dedicated ...  2022-09-02       en
# 4  第238回は、”日本三連覇のラッパー”R-指定と、”世界一のDJ”DJ松永による1MC1DJ...  2022-08-31       ja
#
#                                                 Tags    Views   Likes  \
# 0  [the first take, first take, ファーストテイク, ファステク, ...   496336   31661
# 1  [the first take, first take, ファーストテイク, Tokyo s...  1304895   73096
# 2                                                      396381   12460
# 3  [the first take, first take, ファーストテイク, ファステク, ...  4954962  222317
# 4                                                      319291   10949
#
#    CommentCount                                             Image  \
# 0          1316  https://i.ytimg.com/vi/lNDkODRoLvI/hqdefault.jpg
# 1          2549  https://i.ytimg.com/vi/NJd0-O-IkPY/hqdefault.jpg
# 2           104  https://i.ytimg.com/vi/ZeMsSO6hpms/hqdefault.jpg
# 3          8254  https://i.ytimg.com/vi/_P9zR5KaPsc/hqdefault.jpg
# 4            99  https://i.ytimg.com/vi/q2jz1O4GLWQ/hqdefault.jpg
#
#                                Topic
# 0  [Music, Music_of_Asia, Pop_music]
# 1  [Music, Music_of_Asia, Pop_music]
# 2  [Music, Music_of_Asia, Pop_music]
# 3  [Country_music, Music, Pop_music]
# 4             [Hip_hop_music, Music]

# %%
data_thefirsttake['Tags'][0]
# Out:
# list

# %% [markdown]
# ## 將影片資訊寫入到一個excel中的不同個sheet

# %%
import os 
import numpy as np

# 開一個新的excel並把多個df寫到同excel不同sheet
path = os.path.join(os.getcwd(), 'channel_video_details.xlsx') # 設定路徑及檔名
writer = pd.ExcelWriter(path, engine='xlsxwriter') # 指定引擎openpyxl

data_ado.to_excel(writer, sheet_name='Ado', index=False)
data_thefirsttake.to_excel(writer, sheet_name='The First Take', index=False)
data_2CELLOS.to_excel(writer, sheet_name='2CELLOS', index=False)
data_minami.to_excel(writer, sheet_name='美波', index=False)
data_hoshinogen.to_excel(writer, sheet_name='星野源', index=False)
data_kobasolo.to_excel(writer, sheet_name='Kobasolo', index=False)
data_rurupaino.to_excel(writer, sheet_name='Ru味春捲 Paino', index=False)
data_panpaino.to_excel(writer, sheet_name='Pan Paino', index=False)
data_YOASOBI.to_excel(writer, sheet_name='Yoasobi', index=False)
writer.save()

# %% [markdown]
# ## 可簡易的查看頻道前10名的影片內容，以TheFirstTake為例

# %%
top10_videos = data_thefirsttake.sort_values(by='Views', ascending=False).head(10)
top10_videos
# Out:
#                                                  Title  \
# 385                 DISH// (北村匠海) - 猫 / THE FIRST TAKE
# 372                    YOASOBI - 夜に駆ける / THE HOME TAKE
# 412                        LiSA - 紅蓮華 / THE FIRST TAKE
# 325                      優里 - ドライフラワー / THE FIRST TAKE
# 271                     YOASOBI - 群青  / THE FIRST TAKE
# 331                          LiSA - 炎 / THE FIRST TAKE
# 322  LiSA×Uru - 再会 (produced by Ayase) / THE FIRST ...
# 154                       優里 - ベテルギウス / THE FIRST TAKE
# 312                Def Tech - My Way  / THE FIRST TAKE
# 122  milet×Aimer×幾田りら - おもかげ (produced by Vaundy) /...
#
#                                            Description PublishedAt Language  \
# 385  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2020-03-20       ja
# 372  「THE HOME TAKE」は、アーティストの自宅やプライベートスタジオから、一発撮りで届...  2020-05-15       ja
# 412  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-12-06       ja
# 325  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2020-10-30       ja
# 271  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2021-02-26       ja
# 331  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2020-10-16       ja
# 322  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2020-11-06       ja
# 154  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2021-10-13       ja
# 312  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2020-11-20       ja
# 122  「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2021-12-17       ja
#
#                                                   Tags      Views    Likes  \
# 385  [the first take, first take, ファーストテイク, ファステク, ...  187564447  1174018
# 372  [the first take, first take, ファーストテイク, ファステク, ...  129611302  1671737
# 412  [the first take, first take, ファーストテイク, ファステク, ...  125232464  1343718
# 325  [the first take, first take, ファーストテイク, ファステク, ...  104291818   602716
# 271  [the first take, first take, ファーストテイク, ファステク, ...   76106797  1043614
# 331  [the first take, first take, ファーストテイク, ファステク, ...   58795801   796113
# 322  [the first take, first take, ファーストテイク, ファステク, ...   58513230   537514
# 154  [the first take, first take, ファーストテイク, ファステク, ...   43631713   339740
# 312  [the first take, first take, ファーストテイク, ファステク, ...   37046219   493703
# 122  [the first take, first take, ファーストテイク, ファステク, ...   34577269   485572
#
#      CommentCount                                             Image  \
# 385         47148  https://i.ytimg.com/vi/gsT6eKsnT0M/hqdefault.jpg
# 372         64647  https://i.ytimg.com/vi/j1hft9Wjq9U/hqdefault.jpg
# 412         45481  https://i.ytimg.com/vi/MpYy6wwqxoo/hqdefault.jpg
# 325         19834  https://i.ytimg.com/vi/yXZd7xVdpJ0/hqdefault.jpg
# 271         34775  https://i.ytimg.com/vi/NyUTYwZe_l4/hqdefault.jpg
# 331         28264  https://i.ytimg.com/vi/4Q9DWZLaY2U/hqdefault.jpg
# 322         17076  https://i.ytimg.com/vi/impSuIygMiQ/hqdefault.jpg
# 154          8582  https://i.ytimg.com/vi/-n790YakYKc/hqdefault.jpg
# 312         18064  https://i.ytimg.com/vi/9ZG9G3v1RPk/hqdefault.jpg
# 122         14044  https://i.ytimg.com/vi/Z2Z9V-4DMGw/hqdefault.jpg
#
#                                              Topic
# 385              [Music, Music_of_Asia, Pop_music]
# 372              [Music, Music_of_Asia, Pop_music]
# 412             [Music, Music_of_Asia, Rock_music]
# 325              [Music, Music_of_Asia, Pop_music]
# 271  [Music, Music_of_Asia, Pop_music, Rock_music]
# 331              [Music, Music_of_Asia, Pop_music]
# 322              [Music, Music_of_Asia, Pop_music]
# 154              [Music, Music_of_Asia, Pop_music]
# 312          [Hip_hop_music, Music, Music_of_Asia]
# 122              [Music, Music_of_Asia, Pop_music]

# %%
fig = plt.figure(figsize=(10, 5)) 
color = ['#5975a4', '#cc8963', '#5f9e6e', '#b55e60', '#857aab', '#8d7866', '#d095bf', '#8c8c8c', '#c1b37f', '#00E3E3']
# creating the bar plot 
plt.barh(top10_videos['Title'], top10_videos['Views'], color=color)
plt.xlabel("Views(bn)",fontsize=20) 
plt.ylabel("Songs",fontsize=20) 
plt.title("Top 10 Ado Videos",fontsize=20)
plt.show()

# %% [markdown]
# ## 加入月份

# %%
data_thefirsttake['Month'] = pd.to_datetime(data_thefirsttake['PublishedAt']).dt.strftime('%b')
data_thefirsttake
# Out:
#                                                  Title  \
# 0         Avril Lavigne - Complicated / THE FIRST TAKE
# 1                    Creepy Nuts - 堕天 / THE FIRST TAKE
# 2                          優里 - おにごっこ / THE FIRST TAKE
# 3                             優里 - レオ / THE FIRST TAKE
# 4    Kep1er - WA DA DA (Japanese ver.) / THE FIRST ...
# ..                                                 ...
# 412                        LiSA - 紅蓮華 / THE FIRST TAKE
# 413                        adieu - 天気 / THE FIRST TAKE
# 414  Cö shu Nie - asphyxia （piano ver.) / THE FIRST...
# 415          Rude-α  - It's only love / THE FIRST TAKE
# 416                   adieu  - ナラタージュ / THE FIRST TAKE
#
#                                            Description PublishedAt Language  \
# 0    THE FIRST TAKE is a YouTube Channel dedicated ...  2022-09-02       en
# 1    第238回は、”日本三連覇のラッパー”R-指定と、”世界一のDJ”DJ松永による1MC1DJ...  2022-08-31       ja
# 2    「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-08-31       ja
# 3    第237回は、「シャッター」がストリーミング累計2億回再生を突破し、4曲目の達成で男性ソロア...  2022-08-30       ja
# 4    「THE FIRST TAKE」は、一発撮りのパフォーマンスを鮮明に切り取るYouTubeチ...  2022-08-26       ja
# ..                                                 ...         ...      ...
# 412  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-12-06       ja
# 413  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-12-04       ja
# 414  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-11-29       ja
# 415  「THE FIRST TAKE」は、アーティストの一発撮りのパフォーマンスをよりリアルに、鮮...  2019-11-23       ja
# 416  「THE FIRST TAKE」アーティストの一発撮りのパフォーマンスをよりリアルに、\n鮮...  2019-11-15       ja
#
#                                                   Tags      Views    Likes  \
# 0    [the first take, first take, ファーストテイク, ファステク, ...    3093970   169029
# 1                                                          237373     8417
# 2    [the first take, first take, ファーストテイク, ファステク, ...    5701588    44156
# 3                                                          256895     8436
# 4    [first take, ファーストテイク, ファステク, 一発撮り, 緊張感, COLOR...    3861055   167189
# ..                                                 ...        ...      ...
# 412  [the first take, first take, ファーストテイク, ファステク, ...  125232464  1343718
# 413  [the first take, first take, ファーストテイク, ファステク, ...    1275452    13776
# 414  [the first take, first take, ファーストテイク, ファステク, ...    5924121   163924
# 415  [the first take, first take, ファーストテイク, ファステク, ...    2494841    43993
# 416  [the first take, first take, ファーストテイク, ファステク, ...    5581553    81507
#
#      CommentCount                                             Image  \
# 0            6629  https://i.ytimg.com/vi/_P9zR5KaPsc/hqdefault.jpg
# 1             116  https://i.ytimg.com/vi/q2jz1O4GLWQ/hqdefault.jpg
# 2            2588  https://i.ytimg.com/vi/zXZuqUlAZSk/hqdefault.jpg
# 3             201  https://i.ytimg.com/vi/U73dcua4tag/hqdefault.jpg
# 4            6550  https://i.ytimg.com/vi/EFfiy24kRic/hqdefault.jpg
# ..            ...                                               ...
# 412         45481  https://i.ytimg.com/vi/MpYy6wwqxoo/hqdefault.jpg
# 413           372  https://i.ytimg.com/vi/FT6Wf8EWYwA/hqdefault.jpg
# 414          3682  https://i.ytimg.com/vi/eWPYxw_yqW4/hqdefault.jpg
# 415          1453  https://i.ytimg.com/vi/qdPbnrqs5UQ/hqdefault.jpg
# 416          1726  https://i.ytimg.com/vi/YTKuKuD-gmE/hqdefault.jpg
#
#                                              Topic Month
# 0    [Country_music, Music, Pop_music, Rock_music]   Sep
# 1                           [Hip_hop_music, Music]   Aug
# 2                [Music, Music_of_Asia, Pop_music]   Aug
# 3                               [Music, Pop_music]   Aug
# 4                [Music, Music_of_Asia, Pop_music]   Aug
# ..                                             ...   ...
# 412             [Music, Music_of_Asia, Rock_music]   Dec
# 413              [Music, Music_of_Asia, Pop_music]   Dec
# 414                         [Music, Music_of_Asia]   Nov
# 415              [Music, Music_of_Asia, Pop_music]   Nov
# 416                         [Music, Music_of_Asia]   Nov
#
# [417 rows x 11 columns]

# %% [markdown]
# ## 顯示月份上傳影片數量及排序

# %%
videos_per_month = data_thefirsttake.groupby('Month', as_index=False).size()
videos_per_month
# Out:
#    Month  size
# 0    Apr    35
# 1    Aug    38
# 2    Dec    38
# 3    Feb    34
# 4    Jan    34
# 5    Jul    34
# 6    Jun    43
# 7    Mar    39
# 8    May    35
# 9    Nov    34
# 10   Oct    27
# 11   Sep    26

# %%
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
              'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories = sort_order, ordered=True)
videos_per_month = videos_per_month.sort_index()
videos_per_month
# Out:
#       Month  size
# Month
# Jan     Jan    34
# Feb     Feb    34
# Mar     Mar    39
# Apr     Apr    35
# May     May    35
# Jun     Jun    43
# Jul     Jul    34
# Aug     Aug    38
# Sep     Sep    26
# Oct     Oct    27
# Nov     Nov    34
# Dec     Dec    38

# %%
fig = plt.figure(figsize=(10, 5)) 
color = ['#5975a4', '#cc8963', '#5f9e6e', '#b55e60', '#857aab', '#8d7866', '#d095bf', '#8c8c8c', '#c1b37f', '#00E3E3', '#ff7801','#9edcea']
# creating the bar plot 
plt.bar(videos_per_month['Month'], videos_per_month['size'], color=color) 
  
plt.xlabel("Month",fontsize=20) 
plt.ylabel("Quantity",fontsize=20) 
plt.title("TheFirstTake Videos Uploaded History",fontsize=20)
plt.show()
