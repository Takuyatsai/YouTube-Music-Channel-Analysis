# %% [markdown]
# ## 加入可能會使用的套件

# %%
from googleapiclient.discovery import build
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 設定API參數

# %%
api_service_name = "youtube"
api_version = "v3"
api_key = ''
youtube = build('youtube', 'v3', developerKey = api_key)
channel_id = 'UCAYrMNl92jw6cpjdpBP8JyA'

# %% [markdown]
# ## 取得頻道的資料

# %%
def get_channel_stats(youtube, channel_id):
    all_data = []
    request = youtube.channels().list(
                part="snippet,contentDetails,statistics,topicDetails,brandingSettings,contentOwnerDetails,localizations",
                id= channel_id)
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(ChannelTitle = response['items'][i]['snippet']['title'], # 頻道名稱
                    Description = response['items'][i]['snippet']['description'], # 頻道介紹
                    Published = response['items'][i]['snippet']['publishedAt'], # 頻道創建日期
                    Country = response['items'][i]['snippet']['country'], # 頻道位置
                    Subscribers = response['items'][i]['statistics']['subscriberCount'], # 訂閱人數
                    Views = response['items'][i]['statistics']['viewCount'], # 總觀看人數
                    Playlist = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'], # 總上傳影片id
                    VideoCount = response['items'][i]['statistics']['videoCount'], # 頻道數量
                    Channel_topic = response['items'][i]['topicDetails']['topicCategories'], # 頻道類型
                    Image = response['items'][i]['snippet']['thumbnails']['high']['url'], # 頻道圖片
                    Keywords = '')
        if 'keywords' not in response['items'][i]['brandingSettings']['channel']:
            data['Keywords'] == ''
        else:
            data['Keywords'] = response['items'][i]['brandingSettings']['channel']['keywords']
        all_data.append(data)
    return all_data

# %%
statistics = get_channel_stats(youtube, channel_id)
statistics
# Out:
# [{'ChannelTitle': "Ru's Piano Ru味春捲",
#   'Description': "I’m RuRu, an ACG pianist from Taiwan.\nMaking piano covers and sheets of Anime&Game music.\nIf you like my videos, please subscribe and share to your friends.♬\n\n台湾のACGピアニスト ヾ(´︶`*)ﾉ♬\n主にRuRuのアニソン、ゲーソンのピアノ演奏です～\nチャンネル登録とシェアをよろしくお願いします！\n\n來自台灣的ACG鋼琴家\n主要音樂類型以動漫、電玩為主～\n歡迎訂閱及按下小鈴鐺 |･ω･)ﾉ\n\n🐤Join RuRu's Membership to support me create music videos\n\n🎵Ru's Album\n▶iTunes/Apple Music: https://music.apple.com/us/artist/rus-piano/1532875290\n▶Spotify: https://open.spotify.com/artist/2bPmtm3V3dmYKOFReUjGCA\n▶YouTube Music: https://music.youtube.com/channel/UCla8_Ce0TaG3c2SMGCb2Kag\n▶amazon: https://www.amazon.com/-/zh_TW/gp/product/B08TRSJVL8\n\n🎹 Ru's Piano Sheet Music Website：https://www.mymusicsheet.com/ruspiano \n\n🎵 FB Page➡️ https://www.facebook.com/ruruspiano\n🎵 Instagram➡️ https://www.instagram.com/ruruspiano\n\n🐣支持Ru's Piano🐣\n▶PayPal： https://paypal.me/ruruspringroll\n▶歐付寶： https://bit.ly/donateRuRuSpringRoll\n▶ECPay： https://p.ecpay.com.tw/ED8DB07\n\n🎹合作洽談/Business：rurupianomusic@gmail.com",
#   'Published': '2018-03-14T09:38:37Z',
#   'Country': 'TW',
#   'Subscribers': '2450000',
#   'Views': '335641266',
#   'Playlist': 'UUAYrMNl92jw6cpjdpBP8JyA',
#   'VideoCount': '495',
#   'Channel_topic': ['https://en.wikipedia.org/wiki/Music',
#    'https://en.wikipedia.org/wiki/Music_of_Asia',
#    'https://en.wikipedia.org/wiki/Classical_music'],
#   'Image': 'https://yt3.ggpht.com/ytc/AGIKgqNLsIJJ8bJMswuBIdSq3i9UTUr5n7o20b_OeKj7zos=s800-c-k-c0x00ffffff-no-rj-mo',
#   'Keywords': '鋼琴 Ru味春捲 "Ru\'s Piano" "Ru Piano" Piano ピアノ "Anime Piano" "動漫 鋼琴" Pianist "Piano Cover" RUsPiano 鋼琴女神 "Cosplay Piano" "Cosplay 鋼琴" "ACG ピアノ" ピアノ'}]

# %%
statistics = pd.DataFrame(statistics)
statistics
# Out:
#        ChannelTitle                                        Description  \
# 0  Ru's Piano Ru味春捲  I’m RuRu, an ACG pianist from Taiwan.\nMaking ...
#
#               Published Country Subscribers      Views  \
# 0  2018-03-14T09:38:37Z      TW     2450000  335641266
#
#                    Playlist VideoCount  \
# 0  UUAYrMNl92jw6cpjdpBP8JyA        495
#
#                                        Channel_topic  \
# 0  [https://en.wikipedia.org/wiki/Music, https://...
#
#                                                Image  \
# 0  https://yt3.ggpht.com/ytc/AGIKgqNLsIJJ8bJMswuB...
#
#                                             Keywords
# 0  鋼琴 Ru味春捲 "Ru's Piano" "Ru Piano" Piano ピアノ "An...

# %% [markdown]
# ## 取得頻道中的影片ids

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
              part = 'contentDetails',
              playlistId = playlist_id,
              maxResults = 50) # 50 is max
    response = request.execute()
    
    video_ids = []
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages: 
        if next_page_token is None:
            more_pages = False
        else: # json存在nextPageToken，透過以下取得50以上的videos
            request = youtube.playlistItems().list(
                    part = 'contentDetails',
                    playlistId = playlist_id,
                    pageToken = next_page_token)
            response = request.execute()
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            next_page_token = response.get('nextPageToken')
    print('影片數量:', len(video_ids))
    return video_ids

# %%
playlist_id01 = statistics.loc[statistics['ChannelTitle'] == "Ru's Piano Ru味春捲", 'Playlist'].iloc[0]
playlist_id01
# Out:
# 'UUAYrMNl92jw6cpjdpBP8JyA'

# %%
video_ids01 = get_video_ids(youtube, playlist_id01)
# Out:
# 影片數量: 460

# %% [markdown]
# ## 取得個別影片的資訊

# %%
def get_video_details(youtube, video_ids):
        
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
            
    return pd.DataFrame(all_video_info)

# %%
df = get_video_details(youtube, video_ids01)
df.head()
# Out:
#       video_id      channelTitle  \
# 0  PVG5pTQA7V4  Ru's Piano Ru味春捲
# 1  okWisE3DLbw  Ru's Piano Ru味春捲
# 2  kIGB3gMXnJU  Ru's Piano Ru味春捲
# 3  xItkbYKyoHc  Ru's Piano Ru味春捲
# 4  3iIzhhyFJd4  Ru's Piano Ru味春捲
#
#                                                title  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror Theme「merry-go-rou...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me / Itsumo Nando De...
# 4  Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
#
#                                          description  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror「merry-go-round」Ru'...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me」Piano & Pipa Cove...
# 4  Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
#
#                                                 tags           publishedAt  \
# 0  [Idol, アイドル, Oshi no Ko, 推しの子, Sign wa B, メフィス...  2023-05-13T11:30:10Z
# 1  [かがみの孤城, メリーゴーランド, merry-go-round, かがみの孤城 主題歌,...  2023-05-06T11:30:09Z
# 2  [星間旅行, Honkai: Star Rail, Interstellar Journey...  2023-04-29T11:30:08Z
# 3  [千と千尋の神隠し, Spirited Away, いつも何度でも, 永遠同在, 神隱少女,...  2023-04-26T11:30:11Z
# 4  [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22T11:30:11Z
#
#   viewCount likeCount favouriteCount commentCount duration definition caption
# 0     51770      4786           None          364  PT5M32S         hd    true
# 1    113588      3180           None          345  PT4M23S         hd    true
# 2    163469      4748           None          305  PT1M52S         hd    true
# 3    107004      6999           None          549  PT4M12S         hd    true
# 4    102803      5323           None          375   PT4M6S         hd    true

# %%
# def get_channel_video_detail(youtube, video_ids):
    
#     all_video_stats = []
#     for i in range(0, len(video_ids), 50):
#         request = youtube.videos().list(
#         part = 'snippet, statistics, topicDetails',
#         id=','.join(video_ids[i:i+50]))
#         response = request.execute()
#         for video in response['items']:
#             video_stats = dict(ChannelTitle = video['snippet']['channelTitle'],
#                                VideoTitle = video['snippet']['title'],
#                                Description = video['snippet']['description'],
#                                PublishedAt = video['snippet']['publishedAt'],
#                                Language = '',
#                                Views = video['statistics']['viewCount'],
#                                likeCount = "",
#                                commentCount = '',
#                                favoriteCount = video['statistics']['favoriteCount'],
#                                Image = video['snippet']['thumbnails']['high']['url'],
#                                tags = '',
#                                topicDetails = '')
#             if 'tags' in video['snippet']:video_stats['tags'] = video['snippet']['tags']
#             if 'topicDetails' in video:video_stats['topicDetails'] = video['topicDetails']['topicCategories']
#             if 'defaultAudioLanguage' in video['snippet']:video_stats['Language'] = video['snippet']['defaultAudioLanguage']
#             if 'commentCount' in video['statistics']:video_stats['commentCount'] = video['statistics']['commentCount']
#             if 'likeCount' in video['statistics']:video_stats['likeCount'] = video['statistics']['likeCount']
# #             if 'favoriteCount' in video['statistics']:video_stats['favoriteCount'] = video['statistics']['favoriteCount']
#             all_video_stats.append(video_stats)
#     return all_video_stats

# %%
# video_details01 = get_channel_video_detail(youtube, video_ids01)

# %% [markdown]
# ## 將取得資料的格式轉成表格形式

# %%
data = pd.DataFrame(df)
data.head()
# Out:
#       video_id      channelTitle  \
# 0  PVG5pTQA7V4  Ru's Piano Ru味春捲
# 1  okWisE3DLbw  Ru's Piano Ru味春捲
# 2  kIGB3gMXnJU  Ru's Piano Ru味春捲
# 3  xItkbYKyoHc  Ru's Piano Ru味春捲
# 4  3iIzhhyFJd4  Ru's Piano Ru味春捲
#
#                                                title  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror Theme「merry-go-rou...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me / Itsumo Nando De...
# 4  Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
#
#                                          description  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror「merry-go-round」Ru'...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me」Piano & Pipa Cove...
# 4  Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
#
#                                                 tags           publishedAt  \
# 0  [Idol, アイドル, Oshi no Ko, 推しの子, Sign wa B, メフィス...  2023-05-13T11:30:10Z
# 1  [かがみの孤城, メリーゴーランド, merry-go-round, かがみの孤城 主題歌,...  2023-05-06T11:30:09Z
# 2  [星間旅行, Honkai: Star Rail, Interstellar Journey...  2023-04-29T11:30:08Z
# 3  [千と千尋の神隠し, Spirited Away, いつも何度でも, 永遠同在, 神隱少女,...  2023-04-26T11:30:11Z
# 4  [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22T11:30:11Z
#
#   viewCount likeCount favouriteCount commentCount duration definition caption
# 0     51770      4786           None          364  PT5M32S         hd    true
# 1    113588      3180           None          345  PT4M23S         hd    true
# 2    163469      4748           None          305  PT1M52S         hd    true
# 3    107004      6999           None          549  PT4M12S         hd    true
# 4    102803      5323           None          375   PT4M6S         hd    true

# %% [markdown]
# ## 將文字資料數值化

# %%
def columns_type_format(df):
    df['publishedAt'] = pd.to_datetime(df['publishedAt']).dt.date
    df['viewCount'] = pd.to_numeric(df['viewCount'])
    df['likeCount'] = pd.to_numeric(df['likeCount'])
    df['commentCount'] = pd.to_numeric(df['commentCount'])
    return df.head()

# %%
columns_type_format(data)
# Out:
#       video_id      channelTitle  \
# 0  PVG5pTQA7V4  Ru's Piano Ru味春捲
# 1  okWisE3DLbw  Ru's Piano Ru味春捲
# 2  kIGB3gMXnJU  Ru's Piano Ru味春捲
# 3  xItkbYKyoHc  Ru's Piano Ru味春捲
# 4  3iIzhhyFJd4  Ru's Piano Ru味春捲
#
#                                                title  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror Theme「merry-go-rou...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me / Itsumo Nando De...
# 4  Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
#
#                                          description  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror「merry-go-round」Ru'...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me」Piano & Pipa Cove...
# 4  Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
#
#                                                 tags publishedAt  viewCount  \
# 0  [Idol, アイドル, Oshi no Ko, 推しの子, Sign wa B, メフィス...  2023-05-13      51770
# 1  [かがみの孤城, メリーゴーランド, merry-go-round, かがみの孤城 主題歌,...  2023-05-06     113588
# 2  [星間旅行, Honkai: Star Rail, Interstellar Journey...  2023-04-29     163469
# 3  [千と千尋の神隠し, Spirited Away, いつも何度でも, 永遠同在, 神隱少女,...  2023-04-26     107004
# 4  [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22     102803
#
#    likeCount favouriteCount  commentCount duration definition caption
# 0       4786           None           364  PT5M32S         hd    true
# 1       3180           None           345  PT4M23S         hd    true
# 2       4748           None           305  PT1M52S         hd    true
# 3       6999           None           549  PT4M12S         hd    true
# 4       5323           None           375   PT4M6S         hd    true

# %% [markdown]
# ## 計算使用的標籤及標題長度
# ## 轉換影片時間格式

# %%
data['tagsCount'] = data['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
data['titleLength'] = data['title'].apply(lambda x: 0 if x is None else len(x))

# %%
data['duration']
# Out:
# 0      PT5M32S
# 1      PT4M23S
# 2      PT1M52S
# 3      PT4M12S
# 4       PT4M6S
#         ...
# 455    PT2M21S
# 456    PT3M56S
# 457    PT1M56S
# 458     PT2M7S
# 459    PT2M28S
# Name: duration, Length: 460, dtype: object

# %%
import isodate
data['durationSecs'] = data['duration'].apply(lambda x: isodate.parse_duration(x))
data['durationSecs'] = data['durationSecs'].astype('timedelta64[s]')

# %%
data.head()
# Out:
#       video_id      channelTitle  \
# 0  PVG5pTQA7V4  Ru's Piano Ru味春捲
# 1  okWisE3DLbw  Ru's Piano Ru味春捲
# 2  kIGB3gMXnJU  Ru's Piano Ru味春捲
# 3  xItkbYKyoHc  Ru's Piano Ru味春捲
# 4  3iIzhhyFJd4  Ru's Piano Ru味春捲
#
#                                                title  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror Theme「merry-go-rou...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me / Itsumo Nando De...
# 4  Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
#
#                                          description  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror「merry-go-round」Ru'...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me」Piano & Pipa Cove...
# 4  Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
#
#                                                 tags publishedAt  viewCount  \
# 0  [Idol, アイドル, Oshi no Ko, 推しの子, Sign wa B, メフィス...  2023-05-13      51770
# 1  [かがみの孤城, メリーゴーランド, merry-go-round, かがみの孤城 主題歌,...  2023-05-06     113588
# 2  [星間旅行, Honkai: Star Rail, Interstellar Journey...  2023-04-29     163469
# 3  [千と千尋の神隠し, Spirited Away, いつも何度でも, 永遠同在, 神隱少女,...  2023-04-26     107004
# 4  [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22     102803
#
#    likeCount favouriteCount  commentCount duration definition caption  \
# 0       4786           None           364  PT5M32S         hd    true
# 1       3180           None           345  PT4M23S         hd    true
# 2       4748           None           305  PT1M52S         hd    true
# 3       6999           None           549  PT4M12S         hd    true
# 4       5323           None           375   PT4M6S         hd    true
#
#    tagsCount  titleLength  durationSecs
# 0         49           91         332.0
# 1         34           87         263.0
# 2         36           63         112.0
# 3         42           91         252.0
# 4         47           83         246.0

# %%
max(data['viewCount'])
# Out:
# 20570946

# %%
data.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags              False
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# tagsCount         False
# titleLength       False
# durationSecs      False
# dtype: bool

# %%
data.publishedAt.sort_values().value_counts()
# Out:
# 2018-03-27    1
# 2021-12-11    1
# 2021-12-04    1
# 2021-12-01    1
# 2021-11-27    1
#              ..
# 2020-03-25    1
# 2020-03-21    1
# 2020-03-18    1
# 2020-03-14    1
# 2023-05-13    1
# Name: publishedAt, Length: 460, dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# ## 最好的10支影片

# %%
top10_videos = data.sort_values(by='viewCount', ascending=False).head(10)
top10_videos.head(10)
# Out:
#         video_id      channelTitle  \
# 382  gttNFh4vEA4  Ru's Piano Ru味春捲
# 339  taj88J5RjbY  Ru's Piano Ru味春捲
# 347  rEtZFoZi2tc  Ru's Piano Ru味春捲
# 371  v9h0ghAUNKg  Ru's Piano Ru味春捲
# 332  J2sRoTCJD0k  Ru's Piano Ru味春捲
# 187  G1ONiiK1ZKs  Ru's Piano Ru味春捲
# 327  V8RwHXUtCcw  Ru's Piano Ru味春捲
# 329  E7wPG54cfgI  Ru's Piano Ru味春捲
# 173  cjPoV1ErtZE  Ru's Piano Ru味春捲
# 360  RLv-XocB6-I  Ru's Piano Ru味春捲
#
#                                                  title  \
# 382  DRAGON BALL PIANO MEDLEY - 30,000 Subscribers ...
# 339  Demon Slayer OP「Gurenge」Piano & Violin Cover |...
# 347  NARUTO SHIPPUDEN PIANO MEDLEY - 350,000 Subscr...
# 371  JOJO'S BIZARRE ADVENTURE PIANO MEDLEY - 150,00...
# 332  Demon Slayer EP19「Kamado Tanjiro no Uta」| When...
# 187  NARUTO SAD THEME PIANO MEDLEY | Ru's Piano | N...
# 327  「Giorno's Theme / Il vento d'oro」JoJo Golden W...
# 329  One Punch Man OST「Saitama's Theme / Seigi Shik...
# 173  DRAGON BALL ULTRA INSTINCT PIANO MEDLEY！✨1,800...
# 360       NARUTO - Sadness and Sorrow 哀と悲 - Ru's Piano
#
#                                            description  \
# 382  DRAGON BALL PIANO MEDLEY (30,000 Subscribers S...
# 339  「Gurenge」Demon Slayer: Kimetsu no Yaiba Piano ...
# 347  NARUTO SHIPPUDEN PIANO MEDLEY ✨350,000 Subscri...
# 371  JOJO'S BIZARRE ADVENTURE PIANO MEDLEY (150,000...
# 332  Demon Slayer: Kimetsu no Yaiba EP19 Ending Son...
# 187  NARUTO SAD THEME PIANO MEDLEY | Ru's Piano | N...
# 327  「Giorno's Theme / Il vento d'oro」JoJo Golden W...
# 329  One Punch Man OST「Saitama's Theme / Seigi Shik...
# 173  DRAGON BALL ULTRA INSTINCT PIANO MEDLEY！✨1,800...
# 360  NARUTO OST - Sadness and Sorrow [Piano Cover]\...
#
#                                                   tags publishedAt  viewCount  \
# 382  [CHA-LA HEAD CHA-LA, We Gotta Power, DAN DAN K...  2019-06-15   20570946
# 339  [Nezuko Piano, 明け星, 残響散歌, Aimer, Demon Slayer ...  2019-11-23   11738010
# 347  [20周年記念, NARUTO SHIPPUDEN Music, Hotaru No Hik...  2019-10-26   10508701
# 371  [Bloody Stream, ジョジョの奇妙な冒険, ジョジョ ～その血の運命, メドレー...  2019-07-27    8483998
# 332  [Nezuko Piano, 明け星, 白銀, 残響散歌, 朝が来る, Kamado Tan...  2019-12-21    7402427
# 187  [Naruto Sad Theme, Naruto Sad OST, Naruto Sad ...  2021-07-07    5568832
# 327  [JoJo's Bizarre Adventure:Golden Wind OST, Gio...  2020-01-18    5294490
# 329  [Saitama's Theme, Seigi Shikkou, ワンパンマン 正義執行, ...  2020-01-08    5023987
# 173  [DRAGON BALL, DRAGON BALL Piano, 龍珠 鋼琴, DAN DA...  2021-08-28    4521946
# 360  [哀と悲, Sadness and Sorrow, 哀與悲, 火影 傷心, Naruto S...  2019-09-07    4367731
#
#      likeCount favouriteCount  commentCount  duration definition caption  \
# 382     759628           None         34182   PT12M9S         hd   false
# 339     271774           None          8980   PT4M17S         hd    true
# 347     286521           None         12312  PT11M17S         hd   false
# 371     441556           None         17323  PT10M59S         hd    true
# 332     262046           None          8981   PT5M43S         hd    true
# 187     172516           None          4569  PT18M55S         hd   false
# 327     176957           None          5757   PT5M37S         hd   false
# 329     133355           None          6366   PT5M13S         hd   false
# 173     164709           None          5915  PT22M37S         hd   false
# 360     132429           None          4461   PT4M42S         hd   false
#
#      tagsCount  titleLength  durationSecs
# 382         20           66         729.0
# 339         32           93         257.0
# 347         31           72         677.0
# 371         28           80         659.0
# 332         28           88         343.0
# 187         37           78        1135.0
# 327         27           81         337.0
# 329         31           66         313.0
# 173         33           82        1357.0
# 360         32           44         282.0

# %%
fig = plt.figure(figsize=(10, 5)) 
# ['#5975a4', '#cc8963', '#5f9e6e', '#b55e60', '#857aab', '#8d7866', '#d095bf', '#8c8c8c', '#c1b37f', '#00E3E3']
color = ['#5975a4', '#cc8963', '#5f9e6e', '#b55e60', '#857aab', '#8d7866', '#d095bf', '#8c8c8c', '#c1b37f', '#00E3E3']
# creating the bar plot
font = 'SimHei.ttf'
plt.barh(top10_videos['title'], top10_videos['viewCount'], color=color)
plt.xlabel("viewCount",font = font,fontsize=20) 
plt.ylabel("Songs",font = font,fontsize=20) 
plt.title("Top 10 Videos",font = font,fontsize=20)
plt.show()
# Out:
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12300 (\N{LEFT CORNER BRACKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12301 (\N{RIGHT CORNER BRACKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65281 (\N{FULLWIDTH EXCLAMATION MARK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 10024 (\N{SPARKLES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21696 (\N{CJK UNIFIED IDEOGRAPH-54C0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12392 (\N{HIRAGANA LETTER TO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24754 (\N{CJK UNIFIED IDEOGRAPH-60B2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 影片分佈

# %%
fig = plt.figure(figsize=(8, 5))
plt.subplot(121)
plt.violinplot(data['viewCount'])
plt.subplot(122)
labels = 'viewCount', 'likeCount', 'commentCount'
plt.boxplot([data['viewCount'], data['likeCount'], data['commentCount']], labels = labels, showmeans = True)
plt.subplots_adjust(bottom=0.1, left=0.1, right = 1.2)

# %% [markdown]
# ## 加入年計算影片數量

# %%
data['Year'] = pd.to_datetime(data['publishedAt']).dt.strftime('%Y')
data.head()
# Out:
#       video_id      channelTitle  \
# 0  PVG5pTQA7V4  Ru's Piano Ru味春捲
# 1  okWisE3DLbw  Ru's Piano Ru味春捲
# 2  kIGB3gMXnJU  Ru's Piano Ru味春捲
# 3  xItkbYKyoHc  Ru's Piano Ru味春捲
# 4  3iIzhhyFJd4  Ru's Piano Ru味春捲
#
#                                                title  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror Theme「merry-go-rou...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me / Itsumo Nando De...
# 4  Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
#
#                                          description  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror「merry-go-round」Ru'...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me」Piano & Pipa Cove...
# 4  Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
#
#                                                 tags publishedAt  viewCount  \
# 0  [Idol, アイドル, Oshi no Ko, 推しの子, Sign wa B, メフィス...  2023-05-13      51770
# 1  [かがみの孤城, メリーゴーランド, merry-go-round, かがみの孤城 主題歌,...  2023-05-06     113588
# 2  [星間旅行, Honkai: Star Rail, Interstellar Journey...  2023-04-29     163469
# 3  [千と千尋の神隠し, Spirited Away, いつも何度でも, 永遠同在, 神隱少女,...  2023-04-26     107004
# 4  [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22     102803
#
#    likeCount favouriteCount  commentCount duration definition caption  \
# 0       4786           None           364  PT5M32S         hd    true
# 1       3180           None           345  PT4M23S         hd    true
# 2       4748           None           305  PT1M52S         hd    true
# 3       6999           None           549  PT4M12S         hd    true
# 4       5323           None           375   PT4M6S         hd    true
#
#    tagsCount  titleLength  durationSecs  Year
# 0         49           91         332.0  2023
# 1         34           87         263.0  2023
# 2         36           63         112.0  2023
# 3         42           91         252.0  2023
# 4         47           83         246.0  2023

# %%
videos_per_year = data.groupby('Year', as_index=False).size()
videos_per_year
# Out:
#    Year  size
# 0  2018    41
# 1  2019    88
# 2  2020    93
# 3  2021   100
# 4  2022   104
# 5  2023    34

# %%
fig = plt.figure(figsize=(10, 5)) 
color = ['#5975a4', '#cc8963', '#5f9e6e', '#b55e60', '#857aab', '#8d7866', '#d095bf', '#8c8c8c', '#c1b37f', '#00E3E3', '#ff7801','#9edcea']
# creating the bar plot 
plt.bar(videos_per_year['Year'], videos_per_year['size'], color=color) 
  
plt.xlabel("Year",fontsize=12) 
plt.ylabel("Quantity",fontsize=12) 
plt.title("Videos Uploaded History(Year)",fontsize=12)
plt.show()

# %%
videos_per_year_sum = data.groupby('Year').sum()
videos_per_year_sum
# Out:
#       viewCount  likeCount  commentCount  tagsCount  titleLength  durationSecs
# Year
# 2018    6877525     163413         10139        741         2926        5968.0
# 2019  129805880    4098972        177088       2258         5450       23538.0
# 2020   88265915    3169706        157030       2826         6399       30814.0
# 2021   58502053    2283602        104791       3637         7857       56014.0
# 2022   44736293    1811871         72244       4090         8211      130002.0
# 2023    6308806     281983         15713       1295         2636       45566.0

# %%
year = videos_per_year['Year'].values
videos_per_year_sum.insert(0, 'Year', year)
videos_per_year_sum
# Out:
#       Year  viewCount  likeCount  commentCount  tagsCount  titleLength  \
# Year
# 2018  2018    6877525     163413         10139        741         2926
# 2019  2019  129805880    4098972        177088       2258         5450
# 2020  2020   88265915    3169706        157030       2826         6399
# 2021  2021   58502053    2283602        104791       3637         7857
# 2022  2022   44736293    1811871         72244       4090         8211
# 2023  2023    6308806     281983         15713       1295         2636
#
#       durationSecs
# Year
# 2018        5968.0
# 2019       23538.0
# 2020       30814.0
# 2021       56014.0
# 2022      130002.0
# 2023       45566.0

# %%
avg_year_view = videos_per_year_sum['viewCount'].values / videos_per_year['size'].values
avg_year_view
# Out:
# array([ 167744.51219512, 1475066.81818182,  949095.86021505,
#         585020.53      ,  430156.66346154,  185553.11764706])

# %%
plt.plot(videos_per_year_sum['Year'].values, avg_year_view, markersize="16", marker=".")
plt.xlabel("Year",fontsize=12) 
plt.ylabel("viewCount(m)",fontsize=12) 
plt.title("Average Views(year)",fontsize=12)
plt.grid()
plt.show()

# %% [markdown]
# ## 計算每個月的影片數量

# %%
data['Month'] = pd.to_datetime(data['publishedAt']).dt.strftime('%m')
data.head()
# Out:
#       video_id      channelTitle  \
# 0  PVG5pTQA7V4  Ru's Piano Ru味春捲
# 1  okWisE3DLbw  Ru's Piano Ru味春捲
# 2  kIGB3gMXnJU  Ru's Piano Ru味春捲
# 3  xItkbYKyoHc  Ru's Piano Ru味春捲
# 4  3iIzhhyFJd4  Ru's Piano Ru味春捲
#
#                                                title  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror Theme「merry-go-rou...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me / Itsumo Nando De...
# 4  Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
#
#                                          description  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror「merry-go-round」Ru'...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me」Piano & Pipa Cove...
# 4  Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
#
#                                                 tags publishedAt  viewCount  \
# 0  [Idol, アイドル, Oshi no Ko, 推しの子, Sign wa B, メフィス...  2023-05-13      51770
# 1  [かがみの孤城, メリーゴーランド, merry-go-round, かがみの孤城 主題歌,...  2023-05-06     113588
# 2  [星間旅行, Honkai: Star Rail, Interstellar Journey...  2023-04-29     163469
# 3  [千と千尋の神隠し, Spirited Away, いつも何度でも, 永遠同在, 神隱少女,...  2023-04-26     107004
# 4  [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22     102803
#
#    likeCount favouriteCount  commentCount duration definition caption  \
# 0       4786           None           364  PT5M32S         hd    true
# 1       3180           None           345  PT4M23S         hd    true
# 2       4748           None           305  PT1M52S         hd    true
# 3       6999           None           549  PT4M12S         hd    true
# 4       5323           None           375   PT4M6S         hd    true
#
#    tagsCount  titleLength  durationSecs  Year Month
# 0         49           91         332.0  2023    05
# 1         34           87         263.0  2023    05
# 2         36           63         112.0  2023    04
# 3         42           91         252.0  2023    04
# 4         47           83         246.0  2023    04

# %%
videos_per_month = data.groupby('Month', as_index=False).size()
videos_per_month
# Out:
#    Month  size
# 0     01    40
# 1     02    33
# 2     03    42
# 3     04    44
# 4     05    37
# 5     06    38
# 6     07    39
# 7     08    34
# 8     09    39
# 9     10    38
# 10    11    37
# 11    12    39

# %%
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
              'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
videos_per_month_sum = data.groupby('Month').sum()
videos_per_month_sum
# Out:
#        viewCount  likeCount  commentCount  tagsCount  titleLength  \
# Month
# 01      28030323     986722         39460       1268         3017
# 02      21508291     686711         31560       1046         2384
# 03      17900965     678928         32915       1391         3012
# 04      21260066     775688         38135       1389         3216
# 05      23960040     794303         39199       1179         2631
# 06      36289360    1405394         71475       1213         2733
# 07      36748811    1336063         61769       1183         2757
# 08      39087711    1307270         52062       1057         2461
# 09      20553777     751215         37318       1259         2791
# 10      33782858    1165036         51306       1289         2848
# 11      29318510     943451         40921       1222         2749
# 12      26055760     978766         40885       1351         2880
#
#        durationSecs
# Month
# 01          43529.0
# 02          32164.0
# 03          11850.0
# 04          11169.0
# 05          24189.0
# 06          11018.0
# 07          24332.0
# 08          31554.0
# 09          11159.0
# 10          11538.0
# 11          52400.0
# 12          27000.0

# %%
month_avg_views = videos_per_month_sum['viewCount']/videos_per_month['size'].values
month_avg_views
# Out:
# Month
# 01    7.007581e+05
# 02    6.517664e+05
# 03    4.262135e+05
# 04    4.831833e+05
# 05    6.475686e+05
# 06    9.549832e+05
# 07    9.422772e+05
# 08    1.149639e+06
# 09    5.270199e+05
# 10    8.890226e+05
# 11    7.923922e+05
# 12    6.680964e+05
# Name: viewCount, dtype: float64

# %%
fig = plt.figure(figsize=(10, 5)) 
color = ['#5975a4', '#cc8963', '#5f9e6e', '#b55e60', '#857aab', '#8d7866', '#d095bf', '#8c8c8c', '#c1b37f', '#00E3E3', '#ff7801','#9edcea']
# creating the bar plot 
plt.bar(videos_per_month['Month'], videos_per_month['size'], color=color)
plt.xlabel("Month",fontsize=12) 
plt.ylabel("Quantity",fontsize=12) 
plt.title("Videos Uploaded History(Month)",fontsize=12)
plt.show()

plt.plot(videos_per_month['Month'], month_avg_views, markersize="12", marker=".")
plt.xlabel("Month",fontsize=12) 
plt.ylabel("viewCount",fontsize=12) 
plt.title("Videos viewCount(Month)",fontsize=12)
plt.grid()

# %% [markdown]
# ## 加入每週

# %%
data['publishedAt'] = data['publishedAt'].astype(str)

# %%
from dateutil import parser
# Publish day in the week
data['publishedAt'] = data['publishedAt'].apply(lambda x: parser.parse(x)) 
data['Week'] = data['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
data.head()
# Out:
#       video_id      channelTitle  \
# 0  PVG5pTQA7V4  Ru's Piano Ru味春捲
# 1  okWisE3DLbw  Ru's Piano Ru味春捲
# 2  kIGB3gMXnJU  Ru's Piano Ru味春捲
# 3  xItkbYKyoHc  Ru's Piano Ru味春捲
# 4  3iIzhhyFJd4  Ru's Piano Ru味春捲
#
#                                                title  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror Theme「merry-go-rou...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me / Itsumo Nando De...
# 4  Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
#
#                                          description  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror「merry-go-round」Ru'...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me」Piano & Pipa Cove...
# 4  Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
#
#                                                 tags publishedAt  viewCount  \
# 0  [Idol, アイドル, Oshi no Ko, 推しの子, Sign wa B, メフィス...  2023-05-13      51770
# 1  [かがみの孤城, メリーゴーランド, merry-go-round, かがみの孤城 主題歌,...  2023-05-06     113588
# 2  [星間旅行, Honkai: Star Rail, Interstellar Journey...  2023-04-29     163469
# 3  [千と千尋の神隠し, Spirited Away, いつも何度でも, 永遠同在, 神隱少女,...  2023-04-26     107004
# 4  [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22     102803
#
#    likeCount favouriteCount  commentCount duration definition caption  \
# 0       4786           None           364  PT5M32S         hd    true
# 1       3180           None           345  PT4M23S         hd    true
# 2       4748           None           305  PT1M52S         hd    true
# 3       6999           None           549  PT4M12S         hd    true
# 4       5323           None           375   PT4M6S         hd    true
#
#    tagsCount  titleLength  durationSecs  Year Month       Week
# 0         49           91         332.0  2023    05   Saturday
# 1         34           87         263.0  2023    05   Saturday
# 2         36           63         112.0  2023    04   Saturday
# 3         42           91         252.0  2023    04  Wednesday
# 4         47           83         246.0  2023    04   Saturday

# %%
plt.figure(figsize=(8, 6))
data_colors = ['#5975a4', '#cc8963', '#5f9e6e', '#b55e60', '#857aab', '#ff7801','#9edcea']
day_count = data['Week'].value_counts()
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
plt.bar(weekdays, day_count, color = data_colors)
plt.title('Video Uploaded in Week')
# Out:
# Text(0.5, 1.0, 'Video Uploaded in Week')

# %%
videos_per_week_sum = data.groupby('Week').sum()
videos_per_week_sum
# Out:
#            viewCount  likeCount  commentCount  tagsCount  titleLength  \
# Week
# Friday       2014166      49204          3547        202          807
# Monday        807142      18090           815         93          354
# Saturday   220796643    7804778        343210       7654        17416
# Sunday       1618836      65549          1868        175          606
# Thursday     1513136      43328          1586        120          353
# Tuesday      2151573      62381          2926        188          490
# Wednesday  105594976    3766217        183053       6415        13453
#
#            durationSecs
# Week
# Friday           1804.0
# Monday            730.0
# Saturday        81802.0
# Sunday          86947.0
# Thursday        19648.0
# Tuesday         21884.0
# Wednesday       79087.0

# %%
week_avg_views = data.groupby('Week', as_index=False).size()
week_avg_views
# Out:
#         Week  size
# 0     Friday    12
# 1     Monday     5
# 2   Saturday   234
# 3     Sunday     9
# 4   Thursday     5
# 5    Tuesday     8
# 6  Wednesday   187

# %%
plt.bar(week_avg_views['Week'], videos_per_week_sum['viewCount'].values/10000, color = data_colors)
plt.ylabel('viewCount(m)')
# Out:
# Text(0, 0.5, 'viewCount(m)')

# %% [markdown]
# ## 影片時間

# %%
plt.hist(data['durationSecs'], bins = 50)
plt.xlabel('Durations')
plt.ylabel('Count')
plt.title('Video durations')
plt.show()

# %%
fig = plt.figure()

x1 = data['titleLength']
y1 = data['viewCount']/1000000
plt.subplot(121)
plt.grid()
plt.scatter(x1, y1)
plt.xlabel('titleLength')
plt.ylabel('viewCount(M)')
plt.show()

# %% [markdown]
# ## 留言數與觀看數的關係、喜歡數與觀看數的關係

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.3, wspace=0.5)
x1 = data['commentCount']
y1 = data['viewCount']/1000000
plt.subplot(121)
plt.grid()
plt.scatter(x1, y1)
plt.plot([0,x1.max()],[0,y1.max()], color='orange')
plt.xlabel('commentCount')
plt.ylabel('viewCount')

x2 = data['likeCount']
y2 = data['viewCount']/1000000
plt.subplot(122)
plt.grid()
plt.scatter(x2, y2)
plt.plot([0,x2.max()],[0,y2.max()], color='orange')
plt.xlabel('likeCount')
plt.ylabel('viewCount')
# Out:
# Text(0, 0.5, 'viewCount')

# %% [markdown]
# ## Correlation bewteen tags and Views, and tags and likeCount

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.3, wspace=0.5)
x3 = data['tagsCount']
y3 = data['viewCount']
plt.subplot(121)
plt.grid()
plt.scatter(x3, y3)
plt.plot([0,x3.max()],[0,y3.max()], color='orange')
plt.xlabel('tagsCount')
plt.ylabel('viewCount')

x4 = data['tagsCount']
y4 = data['likeCount']
plt.subplot(122)
plt.grid()
plt.scatter(x4, y4)
plt.plot([0,x4.max()],[0,y4.max()], color='orange')
plt.xlabel('tagsCount')
plt.ylabel('likeCount')
# Out:
# Text(0, 0.5, 'likeCount')

# %%
# from collections import Counter
# all_terms = []
# for terms in data['tags']:
#     all_terms.extend(terms)
# sorted(dict(Counter(all_terms)).items(), key=lambda x:x[1], reverse=True)

# %%
from wordcloud import WordCloud
from PIL import Image
from os import path
# mask = np.array(Image.open("wordcloud.png"))
font_path = 'ttf/GenEiAntiquePv5-M.ttf'
wc = WordCloud(width=1600, height=800, background_color='white', font_path = font_path)
wc.generate_from_frequencies(frequencies=dict(Counter(all_terms)))
plt.figure(figsize=(12, 8))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
data.to_excel('channel_data.xlsx', index=False)

# %%
data.to_csv('channel_data.csv', index=False)
