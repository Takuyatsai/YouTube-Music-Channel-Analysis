# %% [markdown]
# ## 加入可能會使用的套件

# %%
from googleapiclient.discovery import build
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 設定API參數

# %%
api_service_name = "youtube"
api_version = "v3"
api_key = 'AIzaSyDuv01cLfrdAOaNT7ek2tGi9MfTURafy7Q'
youtube = build('youtube', 'v3', developerKey = api_key)
channel_id = 'UCAYrMNl92jw6cpjdpBP8JyA'

# %% [markdown]
# ## 取得頻道的資料

# %%
def get_channel_stats(youtube, channel_id):
    all_data = []
    request = youtube.channels().list(
                part="snippet,contentDetails,statistics,topicDetails,brandingSettings,contentOwnerDetails,localizations",
                id= channel_id)
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(ChannelTitle = response['items'][i]['snippet']['title'], # 頻道名稱
                    Description = response['items'][i]['snippet']['description'], # 頻道介紹
                    Published = response['items'][i]['snippet']['publishedAt'], # 頻道創建日期
                    Country = response['items'][i]['snippet']['country'], # 頻道位置
                    Subscribers = response['items'][i]['statistics']['subscriberCount'], # 訂閱人數
                    Views = response['items'][i]['statistics']['viewCount'], # 總觀看人數
                    Playlist = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'], # 總上傳影片id
                    VideoCount = response['items'][i]['statistics']['videoCount'], # 頻道數量
                    Channel_topic = response['items'][i]['topicDetails']['topicCategories'], # 頻道類型
                    Image = response['items'][i]['snippet']['thumbnails']['high']['url'], # 頻道圖片
                    Keywords = '')
        if 'keywords' not in response['items'][i]['brandingSettings']['channel']:
            data['Keywords'] == ''
        else:
            data['Keywords'] = response['items'][i]['brandingSettings']['channel']['keywords']
        all_data.append(data)
    return all_data

# %%
statistics = get_channel_stats(youtube, channel_id)
statistics
# Out:
# [{'ChannelTitle': "Ru's Piano Ru味春捲",
#   'Description': "I’m RuRu, an ACG pianist from Taiwan.\nMaking piano covers and sheets of Anime&Game music.\nIf you like my videos, please subscribe and share to your friends.♬\n\n台湾のACGピアニスト ヾ(´︶`*)ﾉ♬\n主にRuRuのアニソン、ゲーソンのピアノ演奏です～\nチャンネル登録とシェアをよろしくお願いします！\n\n來自台灣的ACG鋼琴家\n主要音樂類型以動漫、電玩為主～\n歡迎訂閱及按下小鈴鐺 |･ω･)ﾉ\n\n🐤Join RuRu's Membership to support me create music videos\n\n🎵Ru's Album\n▶iTunes/Apple Music: https://music.apple.com/us/artist/rus-piano/1532875290\n▶Spotify: https://open.spotify.com/artist/2bPmtm3V3dmYKOFReUjGCA\n▶YouTube Music: https://music.youtube.com/channel/UCla8_Ce0TaG3c2SMGCb2Kag\n▶amazon: https://www.amazon.com/-/zh_TW/gp/product/B08TRSJVL8\n\n🎹 Ru's Piano Sheet Music Website：https://www.mymusicsheet.com/ruspiano \n\n🎵 FB Page➡️ https://www.facebook.com/ruruspiano\n🎵 Instagram➡️ https://www.instagram.com/ruruspiano\n\n🐣支持Ru's Piano🐣\n▶PayPal： https://paypal.me/ruruspringroll\n▶歐付寶： https://bit.ly/donateRuRuSpringRoll\n▶ECPay： https://p.ecpay.com.tw/ED8DB07\n\n🎹合作洽談/Business：rurupianomusic@gmail.com",
#   'Published': '2018-03-14T09:38:37Z',
#   'Country': 'TW',
#   'Subscribers': '2450000',
#   'Views': '335307042',
#   'Playlist': 'UUAYrMNl92jw6cpjdpBP8JyA',
#   'VideoCount': '495',
#   'Channel_topic': ['https://en.wikipedia.org/wiki/Music_of_Asia',
#    'https://en.wikipedia.org/wiki/Classical_music',
#    'https://en.wikipedia.org/wiki/Music'],
#   'Image': 'https://yt3.ggpht.com/ytc/AGIKgqNLsIJJ8bJMswuBIdSq3i9UTUr5n7o20b_OeKj7zos=s800-c-k-c0x00ffffff-no-rj-mo',
#   'Keywords': '鋼琴 Ru味春捲 "Ru\'s Piano" "Ru Piano" Piano ピアノ "Anime Piano" "動漫 鋼琴" Pianist "Piano Cover" RUsPiano 鋼琴女神 "Cosplay Piano" "Cosplay 鋼琴" "ACG ピアノ" ピアノ'}]

# %%
statistics = pd.DataFrame(ru_statistics)
statistics
# Out:
#        ChannelTitle                                        Description  \
# 0  Ru's Piano Ru味春捲  I’m RuRu, an ACG pianist from Taiwan.\nMaking ...
#
#               Published Country Subscribers      Views  \
# 0  2018-03-14T09:38:37Z      TW     2450000  335307042
#
#                    Playlist VideoCount  \
# 0  UUAYrMNl92jw6cpjdpBP8JyA        495
#
#                                        Channel_topic  \
# 0  [https://en.wikipedia.org/wiki/Classical_music...
#
#                                                Image  \
# 0  https://yt3.ggpht.com/ytc/AGIKgqNLsIJJ8bJMswuB...
#
#                                             Keywords
# 0  鋼琴 Ru味春捲 "Ru's Piano" "Ru Piano" Piano ピアノ "An...

# %% [markdown]
# ## 取得頻道中的影片ids

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
              part = 'contentDetails',
              playlistId = playlist_id,
              maxResults = 50) # 50 is max
    response = request.execute()
    
    video_ids = []
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages: 
        if next_page_token is None:
            more_pages = False
        else: # json存在nextPageToken，透過以下取得50以上的videos
            request = youtube.playlistItems().list(
                    part = 'contentDetails',
                    playlistId = playlist_id,
                    pageToken = next_page_token)
            response = request.execute()
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            next_page_token = response.get('nextPageToken')
    print('影片數量:', len(video_ids))
    return video_ids

# %%
playlist_id01 = statistics.loc[statistics['ChannelTitle'] == "Ru's Piano Ru味春捲", 'Playlist'].iloc[0]
playlist_id01
# Out:
# 'UUAYrMNl92jw6cpjdpBP8JyA'

# %%
video_ids01 = get_video_ids(youtube, playlist_id01)
# Out:
# 影片數量: 460

# %% [markdown]
# ## 取得個別影片的資訊

# %%
def get_video_details(youtube, video_ids):
        
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
            
    return pd.DataFrame(all_video_info)

# %%
df = get_video_details(youtube, video_ids01)
df.head()
# Out:
#       video_id      channelTitle  \
# 0  PVG5pTQA7V4  Ru's Piano Ru味春捲
# 1  okWisE3DLbw  Ru's Piano Ru味春捲
# 2  kIGB3gMXnJU  Ru's Piano Ru味春捲
# 3  xItkbYKyoHc  Ru's Piano Ru味春捲
# 4  3iIzhhyFJd4  Ru's Piano Ru味春捲
#
#                                                title  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror Theme「merry-go-rou...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me / Itsumo Nando De...
# 4  Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
#
#                                          description  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror「merry-go-round」Ru'...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me」Piano & Pipa Cove...
# 4  Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
#
#                                                 tags           publishedAt  \
# 0  [Idol, アイドル, Oshi no Ko, 推しの子, Sign wa B, メフィス...  2023-05-12T14:47:24Z
# 1  [かがみの孤城, メリーゴーランド, merry-go-round, かがみの孤城 主題歌,...  2023-05-06T11:30:09Z
# 2  [星間旅行, Honkai: Star Rail, Interstellar Journey...  2023-04-29T11:30:08Z
# 3  [千と千尋の神隠し, Spirited Away, いつも何度でも, 永遠同在, 神隱少女,...  2023-04-26T11:30:11Z
# 4  [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22T11:30:11Z
#
#   viewCount likeCount favouriteCount commentCount duration definition caption
# 0         3       557           None           81  PT5M32S         hd    true
# 1    109709      3083           None          340  PT4M23S         hd    true
# 2    157977      4546           None          302  PT1M52S         hd    true
# 3    102964      6900           None          547  PT4M12S         hd    true
# 4     97876      5202           None          375   PT4M6S         hd    true

# %%
# def get_channel_video_detail(youtube, video_ids):
    
#     all_video_stats = []
#     for i in range(0, len(video_ids), 50):
#         request = youtube.videos().list(
#         part = 'snippet, statistics, topicDetails',
#         id=','.join(video_ids[i:i+50]))
#         response = request.execute()
#         for video in response['items']:
#             video_stats = dict(ChannelTitle = video['snippet']['channelTitle'],
#                                VideoTitle = video['snippet']['title'],
#                                Description = video['snippet']['description'],
#                                PublishedAt = video['snippet']['publishedAt'],
#                                Language = '',
#                                Views = video['statistics']['viewCount'],
#                                likeCount = "",
#                                commentCount = '',
#                                favoriteCount = video['statistics']['favoriteCount'],
#                                Image = video['snippet']['thumbnails']['high']['url'],
#                                tags = '',
#                                topicDetails = '')
#             if 'tags' in video['snippet']:video_stats['tags'] = video['snippet']['tags']
#             if 'topicDetails' in video:video_stats['topicDetails'] = video['topicDetails']['topicCategories']
#             if 'defaultAudioLanguage' in video['snippet']:video_stats['Language'] = video['snippet']['defaultAudioLanguage']
#             if 'commentCount' in video['statistics']:video_stats['commentCount'] = video['statistics']['commentCount']
#             if 'likeCount' in video['statistics']:video_stats['likeCount'] = video['statistics']['likeCount']
# #             if 'favoriteCount' in video['statistics']:video_stats['favoriteCount'] = video['statistics']['favoriteCount']
#             all_video_stats.append(video_stats)
#     return all_video_stats

# %%
# video_details01 = get_channel_video_detail(youtube, video_ids01)

# %% [markdown]
# ## 將取得資料的格式轉成表格形式

# %%
data = pd.DataFrame(df)
data.head()
# Out:
#       video_id      channelTitle  \
# 0  PVG5pTQA7V4  Ru's Piano Ru味春捲
# 1  okWisE3DLbw  Ru's Piano Ru味春捲
# 2  kIGB3gMXnJU  Ru's Piano Ru味春捲
# 3  xItkbYKyoHc  Ru's Piano Ru味春捲
# 4  3iIzhhyFJd4  Ru's Piano Ru味春捲
#
#                                                title  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror Theme「merry-go-rou...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me / Itsumo Nando De...
# 4  Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
#
#                                          description  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror「merry-go-round」Ru'...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me」Piano & Pipa Cove...
# 4  Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
#
#                                                 tags           publishedAt  \
# 0  [Idol, アイドル, Oshi no Ko, 推しの子, Sign wa B, メフィス...  2023-05-12T14:47:24Z
# 1  [かがみの孤城, メリーゴーランド, merry-go-round, かがみの孤城 主題歌,...  2023-05-06T11:30:09Z
# 2  [星間旅行, Honkai: Star Rail, Interstellar Journey...  2023-04-29T11:30:08Z
# 3  [千と千尋の神隠し, Spirited Away, いつも何度でも, 永遠同在, 神隱少女,...  2023-04-26T11:30:11Z
# 4  [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22T11:30:11Z
#
#   viewCount likeCount favouriteCount commentCount duration definition caption
# 0         3       557           None           81  PT5M32S         hd    true
# 1    109709      3083           None          340  PT4M23S         hd    true
# 2    157977      4546           None          302  PT1M52S         hd    true
# 3    102964      6900           None          547  PT4M12S         hd    true
# 4     97876      5202           None          375   PT4M6S         hd    true

# %% [markdown]
# ## 將文字資料數值化

# %%
def columns_type_format(df):
    df['publishedAt'] = pd.to_datetime(df['publishedAt']).dt.date
    df['viewCount'] = pd.to_numeric(df['viewCount'])
    df['likeCount'] = pd.to_numeric(df['likeCount'])
    df['commentCount'] = pd.to_numeric(df['commentCount'])
    return df.head()

# %%
columns_type_format(data)
# Out:
#       video_id      channelTitle  \
# 0  PVG5pTQA7V4  Ru's Piano Ru味春捲
# 1  okWisE3DLbw  Ru's Piano Ru味春捲
# 2  kIGB3gMXnJU  Ru's Piano Ru味春捲
# 3  xItkbYKyoHc  Ru's Piano Ru味春捲
# 4  3iIzhhyFJd4  Ru's Piano Ru味春捲
#
#                                                title  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror Theme「merry-go-rou...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me / Itsumo Nando De...
# 4  Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
#
#                                          description  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror「merry-go-round」Ru'...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me」Piano & Pipa Cove...
# 4  Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
#
#                                                 tags publishedAt  viewCount  \
# 0  [Idol, アイドル, Oshi no Ko, 推しの子, Sign wa B, メフィス...  2023-05-12          3
# 1  [かがみの孤城, メリーゴーランド, merry-go-round, かがみの孤城 主題歌,...  2023-05-06     109695
# 2  [星間旅行, Honkai: Star Rail, Interstellar Journey...  2023-04-29     157928
# 3  [千と千尋の神隠し, Spirited Away, いつも何度でも, 永遠同在, 神隱少女,...  2023-04-26     102942
# 4  [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22      97855
#
#    likeCount favouriteCount  commentCount duration definition caption
# 0        554           None            81  PT5M32S         hd    true
# 1       3083           None           340  PT4M23S         hd    true
# 2       4546           None           302  PT1M52S         hd    true
# 3       6900           None           547  PT4M12S         hd    true
# 4       5202           None           375   PT4M6S         hd    true

# %% [markdown]
# ## 計算使用的標籤數量

# %%
data['tagsCount'] = data['tags'].apply(lambda x: 0 if x is None else len(x))

# %% [markdown]
# ## 轉換影片時間格式

# %%
data['duration']
# Out:
# 0      PT5M32S
# 1      PT4M23S
# 2      PT1M52S
# 3      PT4M12S
# 4       PT4M6S
#         ...
# 455    PT2M21S
# 456    PT3M56S
# 457    PT1M56S
# 458     PT2M7S
# 459    PT2M28S
# Name: duration, Length: 460, dtype: object

# %%
import isodate
data['durationSecs'] = data['duration'].apply(lambda x: isodate.parse_duration(x))
data['durationSecs'] = data['durationSecs'].astype('timedelta64[s]')

# %%
data.head()
# Out:
#       video_id      channelTitle  \
# 0  PVG5pTQA7V4  Ru's Piano Ru味春捲
# 1  okWisE3DLbw  Ru's Piano Ru味春捲
# 2  kIGB3gMXnJU  Ru's Piano Ru味春捲
# 3  xItkbYKyoHc  Ru's Piano Ru味春捲
# 4  3iIzhhyFJd4  Ru's Piano Ru味春捲
#
#                                                title  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror Theme「merry-go-rou...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me / Itsumo Nando De...
# 4  Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
#
#                                          description  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror「merry-go-round」Ru'...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me」Piano & Pipa Cove...
# 4  Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
#
#                                                 tags           publishedAt  \
# 0  [Idol, アイドル, Oshi no Ko, 推しの子, Sign wa B, メフィス...  2023-05-12T14:47:24Z
# 1  [かがみの孤城, メリーゴーランド, merry-go-round, かがみの孤城 主題歌,...  2023-05-06T11:30:09Z
# 2  [星間旅行, Honkai: Star Rail, Interstellar Journey...  2023-04-29T11:30:08Z
# 3  [千と千尋の神隠し, Spirited Away, いつも何度でも, 永遠同在, 神隱少女,...  2023-04-26T11:30:11Z
# 4  [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22T11:30:11Z
#
#   viewCount likeCount favouriteCount commentCount duration definition caption  \
# 0         3       557           None           81  PT5M32S         hd    true
# 1    109709      3083           None          340  PT4M23S         hd    true
# 2    157977      4546           None          302  PT1M52S         hd    true
# 3    102964      6900           None          547  PT4M12S         hd    true
# 4     97876      5202           None          375   PT4M6S         hd    true
#
#    tagsCount  durationSecs
# 0         49         332.0
# 1         34         263.0
# 2         36         112.0
# 3         42         252.0
# 4         47         246.0

# %%
max(data['viewCount'])
# Out:
# '988403'

# %%
data.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags              False
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# tagsCount         False
# durationSecs      False
# dtype: bool

# %%
data.publishedAt.sort_values().value_counts()
# Out:
# 2018-03-27T06:29:06Z    1
# 2021-12-11T11:30:12Z    1
# 2021-12-04T11:30:11Z    1
# 2021-12-01T11:30:12Z    1
# 2021-11-27T11:30:13Z    1
#                        ..
# 2020-03-25T11:30:16Z    1
# 2020-03-21T11:30:18Z    1
# 2020-03-18T11:30:15Z    1
# 2020-03-14T11:30:15Z    1
# 2023-05-12T14:47:24Z    1
# Name: publishedAt, Length: 460, dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# ## 最好的10支影片

# %%
top10_videos = data.sort_values(by='viewCount', ascending=False).head(10)
top10_videos.head(10)
# Out:
#         video_id      channelTitle  \
# 258  dZbjmmuPLL4  Ru's Piano Ru味春捲
# 346  CFawH7V8aN4  Ru's Piano Ru味春捲
# 4    3iIzhhyFJd4  Ru's Piano Ru味春捲
# 185  W_wSQTWtfdg  Ru's Piano Ru味春捲
# 436  vCTbISRN-W0  Ru's Piano Ru味春捲
# 416  u8mD_gUS64E  Ru's Piano Ru味春捲
# 340  qPfmjyUAjLk  Ru's Piano Ru味春捲
# 392  j00iqH54KTI  Ru's Piano Ru味春捲
# 242  STbRDthlYpU  Ru's Piano Ru味春捲
# 23   iw_EA34Omyk  Ru's Piano Ru味春捲
#
#                                                  title  \
# 258  「Weight of the World / 壊レタ世界ノ歌」NieR: Automata ...
# 346  Fullmetal Alchemist: Brotherhood OP1『Again』Ru'...
# 4    Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
# 185  Monster Hunter「Proof of a Hero 英雄の証」Ru's Piano...
# 436  【Ru's Piano】英雄の証x古代樹の森 主題曲  | Monster Hunter :...
# 416  【Ru's Piano】OVERLORD III OP「VORACITY」| 不死者之王 P...
# 340  【Deemo】Nine Point Eight - Ru's Piano Cover《DEE...
# 392  Carole & Tuesday OST "The Loneliest Girl" Pian...
# 242  Attack on Titan OP6「My War / Boku no Sensou」Ru...
# 23   Slam Dunk OST「Endless Chain / BAAD」Ru's Piano ...
#
#                                            description  \
# 258  Weight of the World  / 壊レタ世界ノ歌 - NieR: Automat...
# 346  Fullmetal Alchemist: Brotherhood OP1 - Again [...
# 4    Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
# 185  Monster Hunter「Proof of a Hero 英雄の証」Ru's Piano...
# 436  英雄の証x古代樹の森 主題曲  | Monster Hunter : World 魔物獵人世...
# 416  OVERLORD III OP「VORACITY」Piano Cover\n\nI am v...
# 340  Deemo - Nine Point Eight [Piano Cover]\n\nPian...
# 392  Carole & Tuesday OST - The Loneliest Girl [Pia...
# 242  Attack on Titan OP6「My War / Boku no Sensou」Ru...
# 23   Slam Dunk OST「Endless Chain / BAAD」Ru's Piano ...
#
#                                                   tags           publishedAt  \
# 258  [壊レタ世界ノ歌, Weight of the World, 毀壞的世界之歌, NieR: ...  2020-10-10T11:30:11Z
# 346  [Fullmetal Alchemist OP1, Again YUI, 鋼の錬金術師, 鋼...  2019-10-30T11:30:16Z
# 4    [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22T11:30:11Z
# 185  [Monster Hunter, Monster Hunter Main Theme, Mo...  2021-07-14T11:30:12Z
# 436  [魔物獵人, MHW, Monster Hunter Worid, Ru味春捲, 樂譜, 電...  2018-09-22T09:32:42Z
# 416  [動漫音樂, 動漫演奏, 鋼琴演奏, Piano Cover, ブルーバード, オーバーロー...  2019-01-12T11:28:45Z
# 340  [Nine Point Eight, Deemo Music, DEEMO -Reborn-...  2019-11-20T11:30:13Z
# 392  [キャロル&チューズデイ, 卡羅爾與星期二, 卡罗尔与星期二, The Loneliest ...  2019-05-08T11:27:46Z
# 242  [AOT 139, Attack on Titan 139, My War, Attack ...  2020-12-16T11:30:13Z
# 23   [Slam Dunk, Endless Chain, Slam Dunk OST, BAAD...  2023-02-11T11:30:08Z
#
#     viewCount likeCount favouriteCount commentCount duration definition  \
# 258    988403     46866           None         2116  PT6M28S         hd
# 346    979037     34845           None         1241  PT4M57S         hd
# 4       97876      5202           None          375   PT4M6S         hd
# 185     97366      5327           None          491  PT4M44S         hd
# 436     97183      1575           None          110  PT2M25S         hd
# 416     97021      4145           None          201  PT1M36S         hd
# 340     96939      3815           None          317  PT3M37S         hd
# 392     96801      3465           None          160  PT3M44S         hd
# 242    966806     57690           None         1821  PT1M54S         hd
# 23      95707      2568           None          298  PT3M57S         hd
#
#     caption  tagsCount  durationSecs
# 258    true         28         388.0
# 346    true         28         297.0
# 4      true         47         246.0
# 185   false         40         284.0
# 436   false         14         145.0
# 416    true         15          96.0
# 340    true         11         217.0
# 392   false         19         224.0
# 242    true         33         114.0
# 23     true         38         237.0

# %%
fig = plt.figure(figsize=(10, 5)) 
# ['#5975a4', '#cc8963', '#5f9e6e', '#b55e60', '#857aab', '#8d7866', '#d095bf', '#8c8c8c', '#c1b37f', '#00E3E3']
color = ['#5975a4', '#cc8963', '#5f9e6e', '#b55e60', '#857aab', '#8d7866', '#d095bf', '#8c8c8c', '#c1b37f', '#00E3E3']
# creating the bar plot
font = 'SimHei.ttf'
plt.barh(top10_videos['title'], top10_videos['viewCount'], color=color)
plt.xlabel("viewCount",font = font,fontsize=20) 
plt.ylabel("Songs",font = font,fontsize=20) 
plt.title("Top 10 Videos",font = font,fontsize=20)
plt.show()
# Out:
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12300 (\N{LEFT CORNER BRACKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22730 (\N{CJK UNIFIED IDEOGRAPH-58CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12524 (\N{KATAKANA LETTER RE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12479 (\N{KATAKANA LETTER TA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 19990 (\N{CJK UNIFIED IDEOGRAPH-4E16}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30028 (\N{CJK UNIFIED IDEOGRAPH-754C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12494 (\N{KATAKANA LETTER NO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27468 (\N{CJK UNIFIED IDEOGRAPH-6B4C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12301 (\N{RIGHT CORNER BRACKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12302 (\N{LEFT WHITE CORNER BRACKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12303 (\N{RIGHT WHITE CORNER BRACKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 33521 (\N{CJK UNIFIED IDEOGRAPH-82F1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38596 (\N{CJK UNIFIED IDEOGRAPH-96C4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 35388 (\N{CJK UNIFIED IDEOGRAPH-8A3C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65281 (\N{FULLWIDTH EXCLAMATION MARK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129412 (\N{UNICORN FACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12304 (\N{LEFT BLACK LENTICULAR BRACKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12305 (\N{RIGHT BLACK LENTICULAR BRACKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21476 (\N{CJK UNIFIED IDEOGRAPH-53E4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20195 (\N{CJK UNIFIED IDEOGRAPH-4EE3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27193 (\N{CJK UNIFIED IDEOGRAPH-6A39}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26862 (\N{CJK UNIFIED IDEOGRAPH-68EE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20027 (\N{CJK UNIFIED IDEOGRAPH-4E3B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38988 (\N{CJK UNIFIED IDEOGRAPH-984C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26354 (\N{CJK UNIFIED IDEOGRAPH-66F2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 39764 (\N{CJK UNIFIED IDEOGRAPH-9B54}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29289 (\N{CJK UNIFIED IDEOGRAPH-7269}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29557 (\N{CJK UNIFIED IDEOGRAPH-7375}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20154 (\N{CJK UNIFIED IDEOGRAPH-4EBA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38651 (\N{CJK UNIFIED IDEOGRAPH-96FB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29609 (\N{CJK UNIFIED IDEOGRAPH-73A9}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38899 (\N{CJK UNIFIED IDEOGRAPH-97F3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27138 (\N{CJK UNIFIED IDEOGRAPH-6A02}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 19981 (\N{CJK UNIFIED IDEOGRAPH-4E0D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27515 (\N{CJK UNIFIED IDEOGRAPH-6B7B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 32773 (\N{CJK UNIFIED IDEOGRAPH-8005}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20043 (\N{CJK UNIFIED IDEOGRAPH-4E4B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29579 (\N{CJK UNIFIED IDEOGRAPH-738B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21205 (\N{CJK UNIFIED IDEOGRAPH-52D5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 28459 (\N{CJK UNIFIED IDEOGRAPH-6F2B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12298 (\N{LEFT DOUBLE ANGLE BRACKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12299 (\N{RIGHT DOUBLE ANGLE BRACKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12461 (\N{KATAKANA LETTER KI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12515 (\N{KATAKANA LETTER SMALL YA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12525 (\N{KATAKANA LETTER RO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12523 (\N{KATAKANA LETTER RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12481 (\N{KATAKANA LETTER TI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12517 (\N{KATAKANA LETTER SMALL YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12474 (\N{KATAKANA LETTER ZU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12487 (\N{KATAKANA LETTER DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/takuya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12452 (\N{KATAKANA LETTER I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 影片分佈

# %%
fig = plt.figure(figsize=(8, 5))
plt.subplot(121)
plt.violinplot(data['viewCount'])
plt.subplot(122)
labels = 'viewCount', 'likeCount', 'commentCount'
plt.boxplot([data['viewCount'], data['likeCount'], data['commentCount']], labels = labels, showmeans = True)
plt.subplots_adjust(bottom=0.1, left=0.1, right = 1.2)

# %% [markdown]
# ## 加入年計算影片數量

# %%
data['Year'] = pd.to_datetime(data['publishedAt']).dt.strftime('%Y')
data.head()
# Out:
#       video_id      channelTitle  \
# 0  PVG5pTQA7V4  Ru's Piano Ru味春捲
# 1  okWisE3DLbw  Ru's Piano Ru味春捲
# 2  kIGB3gMXnJU  Ru's Piano Ru味春捲
# 3  xItkbYKyoHc  Ru's Piano Ru味春捲
# 4  3iIzhhyFJd4  Ru's Piano Ru味春捲
#
#                                                title  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror Theme「merry-go-rou...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me / Itsumo Nando De...
# 4  Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
#
#                                          description  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror「merry-go-round」Ru'...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me」Piano & Pipa Cove...
# 4  Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
#
#                                                 tags publishedAt  tagsNum  \
# 0  [Idol, アイドル, Oshi no Ko, 推しの子, Sign wa B, メフィス...  2023-05-12       49
# 1  [かがみの孤城, メリーゴーランド, merry-go-round, かがみの孤城 主題歌,...  2023-05-06       34
# 2  [星間旅行, Honkai: Star Rail, Interstellar Journey...  2023-04-29       36
# 3  [千と千尋の神隠し, Spirited Away, いつも何度でも, 永遠同在, 神隱少女,...  2023-04-26       42
# 4  [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22       47
#
#    viewCount  likeCount favouriteCount  commentCount duration definition  \
# 0          3        554           None            81  PT5M32S         hd
# 1     109695       3083           None           340  PT4M23S         hd
# 2     157928       4546           None           302  PT1M52S         hd
# 3     102942       6900           None           547  PT4M12S         hd
# 4      97855       5202           None           375   PT4M6S         hd
#
#   caption  Year
# 0    true  2023
# 1    true  2023
# 2    true  2023
# 3    true  2023
# 4    true  2023

# %%
videos_per_year = data.groupby('Year', as_index=False).size()
videos_per_year
# Out:
#    Year  size
# 0  2018    41
# 1  2019    88
# 2  2020    93
# 3  2021   100
# 4  2022   104
# 5  2023    34

# %%
fig = plt.figure(figsize=(10, 5)) 
color = ['#5975a4', '#cc8963', '#5f9e6e', '#b55e60', '#857aab', '#8d7866', '#d095bf', '#8c8c8c', '#c1b37f', '#00E3E3', '#ff7801','#9edcea']
# creating the bar plot 
plt.bar(videos_per_year['Year'], videos_per_year['size'], color=color) 
  
plt.xlabel("Year",fontsize=12) 
plt.ylabel("Quantity",fontsize=12) 
plt.title("Videos Uploaded History(Year)",fontsize=12)
plt.show()

# %%
videos_per_year_sum = data.groupby('Year').sum()
videos_per_year_sum
# Out:
#       tagsNum  viewCount  likeCount  commentCount
# Year
# 2018      741    6876386     163395         10145
# 2019     2258  129766592    4098097        177074
# 2020     2826   88241268    3169295        157018
# 2021     3637   58455771    2282603        104765
# 2022     4090   44668567    1810666         72217
# 2023     1295    6169176     275709         15385

# %%
year = videos_per_year['Year'].values
videos_per_year_sum.insert(0, 'Year', year)
videos_per_year_sum
# Out:
#       Year  tagsNum  viewCount  likeCount  commentCount
# Year
# 2018  2018      741    6876386     163395         10145
# 2019  2019     2258  129766592    4098097        177074
# 2020  2020     2826   88241268    3169295        157018
# 2021  2021     3637   58455771    2282603        104765
# 2022  2022     4090   44668567    1810666         72217
# 2023  2023     1295    6169176     275709         15385

# %%
avg_year_view = videos_per_year_sum['viewCount'].values / videos_per_year['size'].values
avg_year_view
# Out:
# array([ 167716.73170732, 1474620.36363636,  948830.83870968,
#         584557.71      ,  429505.45192308,  181446.35294118])

# %%
plt.plot(videos_per_year_sum['Year'].values, avg_year_view, markersize="16", marker=".")
plt.xlabel("Year",fontsize=12) 
plt.ylabel("viewCount(m)",fontsize=12) 
plt.title("Average Views(year)",fontsize=12)
plt.grid()
plt.show()

# %% [markdown]
# ## 計算每個月的影片數量

# %%
data['Month'] = pd.to_datetime(data['publishedAt']).dt.strftime('%m')
data.head()
# Out:
#       video_id      channelTitle  \
# 0  PVG5pTQA7V4  Ru's Piano Ru味春捲
# 1  okWisE3DLbw  Ru's Piano Ru味春捲
# 2  kIGB3gMXnJU  Ru's Piano Ru味春捲
# 3  xItkbYKyoHc  Ru's Piano Ru味春捲
# 4  3iIzhhyFJd4  Ru's Piano Ru味春捲
#
#                                                title  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror Theme「merry-go-rou...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me / Itsumo Nando De...
# 4  Oshi no Ko ED「Mephisto / QUEEN BEE」Full Ver. P...
#
#                                          description  \
# 0  Oshi no Ko The Best Piano Medley「Idol / Sign w...
# 1  Lonely Castle in the Mirror「merry-go-round」Ru'...
# 2  Honkai: Star Rail OP「Interstellar Journey 星間旅行...
# 3  Spirited Away「Always With Me」Piano & Pipa Cove...
# 4  Oshi no Ko ED「Mephisto」Full Ver. Piano Cover\n...
#
#                                                 tags publishedAt  tagsNum  \
# 0  [Idol, アイドル, Oshi no Ko, 推しの子, Sign wa B, メフィス...  2023-05-12       49
# 1  [かがみの孤城, メリーゴーランド, merry-go-round, かがみの孤城 主題歌,...  2023-05-06       34
# 2  [星間旅行, Honkai: Star Rail, Interstellar Journey...  2023-04-29       36
# 3  [千と千尋の神隠し, Spirited Away, いつも何度でも, 永遠同在, 神隱少女,...  2023-04-26       42
# 4  [メフィスト, 推しの子 ED, Oshi no Ko, Mephisto, Oshi no...  2023-04-22       47
#
#    viewCount  likeCount favouriteCount  commentCount duration definition  \
# 0          3        554           None            81  PT5M32S         hd
# 1     109695       3083           None           340  PT4M23S         hd
# 2     157928       4546           None           302  PT1M52S         hd
# 3     102942       6900           None           547  PT4M12S         hd
# 4      97855       5202           None           375   PT4M6S         hd
#
#   caption  Year Month
# 0    true  2023    05
# 1    true  2023    05
# 2    true  2023    04
# 3    true  2023    04
# 4    true  2023    04

# %%
videos_per_month = data.groupby('Month', as_index=False).size()
videos_per_month
# Out:
#    Month  size
# 0     01    40
# 1     02    33
# 2     03    42
# 3     04    44
# 4     05    37
# 5     06    38
# 6     07    39
# 7     08    34
# 8     09    39
# 9     10    38
# 10    11    37
# 11    12    39

# %%
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
              'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
videos_per_month_sum = data.groupby('Month').sum()
videos_per_month_sum
# Out:
#        tagsNum  viewCount  likeCount  commentCount
# Month
# 01        1268   28012952     986341         39456
# 02        1046   21488666     686401         31553
# 03        1391   17877007     678338         32905
# 04        1389   21197599     774374         38106
# 05        1179   23890976     789662         38897
# 06        1213   36264182    1404801         71462
# 07        1183   36732701    1335731         61756
# 08        1057   39071415    1306905         52054
# 09        1259   20545037     751060         37313
# 10        1289   33755075    1164570         51298
# 11        1222   29299963     942988         40919
# 12        1351   26042187     978594         40885

# %%
month_avg_views = videos_per_month_sum['viewCount']/videos_per_month['size'].values
month_avg_views
# Out:
# Month
# 01    7.003238e+05
# 02    6.511717e+05
# 03    4.256430e+05
# 04    4.817636e+05
# 05    6.457021e+05
# 06    9.543206e+05
# 07    9.418641e+05
# 08    1.149159e+06
# 09    5.267958e+05
# 10    8.882914e+05
# 11    7.918909e+05
# 12    6.677484e+05
# Name: viewCount, dtype: float64

# %%
fig = plt.figure(figsize=(10, 5)) 
color = ['#5975a4', '#cc8963', '#5f9e6e', '#b55e60', '#857aab', '#8d7866', '#d095bf', '#8c8c8c', '#c1b37f', '#00E3E3', '#ff7801','#9edcea']
# creating the bar plot 
plt.bar(videos_per_month['Month'], videos_per_month['size'], color=color)
plt.xlabel("Month",fontsize=12) 
plt.ylabel("Quantity",fontsize=12) 
plt.title("Videos Uploaded History(Month)",fontsize=12)
plt.show()

plt.plot(videos_per_month['Month'], month_avg_views, markersize="12", marker=".")
plt.xlabel("Month",fontsize=12) 
plt.ylabel("viewCount",fontsize=12) 
plt.title("Videos viewCount(Month)",fontsize=12)
plt.grid()

# %% [markdown]
# ## 留言數與觀看數的關係、喜歡數與觀看數的關係

# %%
fig = plt.figure()

x1 = data['commentCount']
y1 = data['viewCount']
plt.subplot(121)
plt.grid()
plt.scatter(x1, y1)
plt.plot([0,x1.max()],[0,y1.max()], color='orange')
plt.xlabel('commentCount')
plt.ylabel('viewCount')

x2 = data['likeCount']
y2 = data['viewCount']
plt.subplot(122)
plt.grid()
plt.scatter(x2, y2)
plt.plot([0,x2.max()],[0,y2.max()], color='orange')
plt.xlabel('likeCount')
plt.ylabel('viewCount')
# Out:
# Text(0, 0.5, 'viewCount')

# %% [markdown]
# ## Correlation bewteen tags and Views, and tags and likeCount

# %%
fig = plt.figure()

x3 = data['tagsNum']
y3 = data['viewCount']
plt.subplot(121)
plt.grid()
plt.scatter(x3, y3)
plt.plot([0,x3.max()],[0,y3.max()], color='orange')
plt.xlabel('tagsNum')
plt.ylabel('viewCount')

x4 = data['tagsNum']
y4 = data['likeCount']
plt.subplot(122)
plt.grid()
plt.scatter(x4, y4)
plt.plot([0,x4.max()],[0,y4.max()], color='orange')
plt.xlabel('tagsNum')
plt.ylabel('likeCount')
# Out:
# Text(0, 0.5, 'likeCount')

# %%
# from collections import Counter
# all_terms = []
# for terms in data['tags']:
#     all_terms.extend(terms)
# sorted(dict(Counter(all_terms)).items(), key=lambda x:x[1], reverse=True)

# %%
from wordcloud import WordCloud
from PIL import Image
from os import path
# mask = np.array(Image.open("wordcloud.png"))
font_path = 'ttf/GenEiAntiquePv5-M.ttf'
wc = WordCloud(width=1600, height=800, background_color='white', font_path = font_path)
wc.generate_from_frequencies(frequencies=dict(Counter(all_terms)))
plt.figure(figsize=(12, 8))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
data.to_excel('yutube_data.xlsx', index=False)

# %%
data.to_csv('yutube_data.csv', index=False)
